# %% [markdown]
# <a href="https://colab.research.google.com/github/21P31A0406/Python-libraries/blob/main/Pandas_MassCoders.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Importing Pandas**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # **Pandas**
#
# **Pandas** is a powerful **Python library for data manipulation and analysis.** It provides easy-to-use data structures and functions to work with structured data like tabular, time series, or matrix data.
#
# **Pandas primarily provides two data structures: Series and DataFrame.**
#
# **Series:** A one-dimensional labeled array capable of holding any data type.
#
# **DataFrame:** A two-dimensional labeled data structure with columns of potentially different types.

# %% [markdown]
# # **Pandas - Series**
#
# **Series** in pandas is a fundamental data structure that represents a one-dimensional array of indexed data. It can hold any type of **data—integers, strings, floats, Python objects**, etc. The Series object is built on top of the NumPy array and is very similar to it but with additional capabilities like handling missing data. The indices of a pandas Series are more flexible than those in a simple NumPy array.

# %% [markdown]
# # Creating a Series

# %%
s = pd.Series([1, 3, 5, 7, 9])
print(s)
# Out:
# 0    1
# 1    3
# 2    5
# 3    7
# 4    9
# dtype: int64

# %% [markdown]
# **Key Attributes**
#
# **Values:** The data in the Series.
#
# **Index:** The index (labels) of each data point.

# %% [markdown]
# # **Common Methods of Series**

# %% [markdown]
# # Descriptive Statistics

# %% [markdown]
# **s.describe():** Provides a quick summary of the data.
#
# This method gives a statistical summary of the Series, including count, mean, standard deviation, minimum, maximum, and quartile values.

# %%
# Creating a Series
s = pd.Series([1, 3, 5, 7, 9])

# Descriptive statistics
print(s.describe())
# Out:
# count    5.000000
# mean     5.000000
# std      3.162278
# min      1.000000
# 25%      3.000000
# 50%      5.000000
# 75%      7.000000
# max      9.000000
# dtype: float64

# %% [markdown]
# **s.mean():** Computes the mean of the data.

# %%
# Mean of the Series
print(s.mean())
# Out:
# 5.0

# %% [markdown]
# **s.std():** Computes the standard deviation.

# %%
# Standard deviation of the Series
print(s.std())
# Out:
# 3.1622776601683795

# %% [markdown]
# **s.min() and s.max():** Computes the minimum and maximum values.

# %%
# Minimum and maximum values
print(s.min())
print(s.max())
# Out:
# 1
# 9

# %% [markdown]
# # Data Manipulation

# %% [markdown]
# **s.map(func):** Applies a function to each element in the Series.

# %%
# Mapping function to double the values
doubled = s.map(lambda x: x * 2)
print(doubled)
# Out:
# 0     2
# 1     6
# 2    10
# 3    14
# 4    18
# dtype: int64

# %% [markdown]
# **s.apply(func):** Similar to map, but more flexible. (Can be used Data Frames as well, where as map is only for Series)

# %%
# Applying a function to calculate square root
sqrt = s.apply(lambda x: x ** 0.5)
print(sqrt)
# Out:
# 0    1.000000
# 1    1.732051
# 2    2.236068
# 3    2.645751
# 4    3.000000
# dtype: float64

# %% [markdown]
# **s.sort_values():** Sorts the Series.

# %%
# Sorting the Series
sorted_s = s.sort_values()
print(sorted_s)
# Out:
# 0    1
# 1    3
# 2    5
# 3    7
# 4    9
# dtype: int64

# %% [markdown]
# **s.drop(labels):** Drops specified labels from the Series.

# %%
# Dropping the first element
dropped = s.drop(0)
print(dropped)
# Out:
# 1    3
# 2    5
# 3    7
# 4    9
# dtype: int64

# %%
print(s)
# Out:
# 0    1
# 1    3
# 2    5
# 3    7
# 4    9
# dtype: int64

# %% [markdown]
# # Handling Missing Data

# %% [markdown]
# **s.isnull():** Checks for missing values, returns a Series of booleans.

# %%
# Checking for missing values
print(s.isnull())
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %% [markdown]
# **s.notnull():** Opposite of isnull().

# %%
# Checking for non-null values
print(s.notnull())
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# dtype: bool

# %% [markdown]
# **s.fillna(value):** Fills missing values with a specified value.

# %%
# Create a Series with missing values
s = pd.Series([1, 2, np.nan, 4, np.nan])

# Print the Series
print(s)
# Out:
# 0    1.0
# 1    2.0
# 2    NaN
# 3    4.0
# 4    NaN
# dtype: float64

# %%
# Filling missing values with 0
filled = s.fillna(9)
print(filled)
# Out:
# 0    1.0
# 1    2.0
# 2    9.0
# 3    4.0
# 4    9.0
# dtype: float64

# %% [markdown]
# **s.dropna():** Drops all rows that contain missing values.

# %%
# Creating a Series with missing values
s_with_missing = pd.Series([1, 2, None, 4, 5])

# Dropping missing values
dropped_missing = s_with_missing.dropna()
print(dropped_missing)
# Out:
# 0    1.0
# 1    2.0
# 3    4.0
# 4    5.0
# dtype: float64

# %% [markdown]
# # Indexing, Slicing, and Filtering

# %% [markdown]
# **s.iloc[ ]:** Purely integer-location based indexing.

# %%
# Indexing by position
s = pd.Series([1, 3, 5, 7, 9])
print(s.iloc[0])  # First element
print(s.iloc[-1])  # Last element
# Out:
# 1
# 9

# %% [markdown]
# **s.loc[ ]:** Label-based indexing.

# %%
# Indexing by label
print(s.loc[0])  # First element
print(s.loc[4])  # Last element
# Out:
# 1
# 9

# %%
# Create a Series
s = pd.Series([10, 20, 30, 40], index=['a', 'b', 'c', 'd'])
print(s)
# Accessing elements using iloc
print(s.iloc[0])  # Access the first element
print(s.iloc[1:3])  # Access elements at positions 1 and 2 (exclusive of 3)

# Accessing elements using loc
print(s.loc['a'])  # Access the element with index label 'a'
print(s.loc['b':'c'])  # Access elements with index labels 'b' and 'c'
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64
# 10
# b    20
# c    30
# dtype: int64
# 10
# b    20
# c    30
# dtype: int64

# %% [markdown]
# **s[s > n]:** Filters and returns elements greater than n.

# %%
# Filtering elements greater than 5
filtered = s[s > 5]
print(filtered)
# Out:
# 3    7
# 4    9
# dtype: int64

# %% [markdown]
# # Aggregation

# %% [markdown]
# **s.sum():** Sums up the values.

# %%
# Sum of the Series
print(s.sum())
# Out:
# 25

# %% [markdown]
# **s.cumsum():** Cumulative sum.

# %%
# Cumulative sum of the Series
print(s)
print(s.cumsum())
# Out:
# 0    1
# 1    3
# 2    5
# 3    7
# 4    9
# dtype: int64
# 0     1
# 1     4
# 2     9
# 3    16
# 4    25
# dtype: int64

# %% [markdown]
# **s.aggregate(func):** Aggregates using one or more operations.

# %%
# Aggregating using multiple operations
aggregated = s.aggregate(['sum', 'mean', 'std'])
print(aggregated)
# Out:
# sum     25.000000
# mean     5.000000
# std      3.162278
# dtype: float64

# %% [markdown]
# # Creating Data Frame

# %%
# Define data
data = {
    'Name': ['Dodagatta Nihar', 'Vignesh', 'Maheshwar', 'Naman', 'Naveen', 'Shreya', 'Varsha', 'Varun'],
    'Role': ['Founder', 'Growth Manager', 'Community Manager', 'Community Manager', 'Community Manager',
             'Course Designer', 'Course Designer', 'Public Relations Manager'],
    'Phone Number': ['111-111-1111', '222-222-2222', '333-333-3333', '444-444-4444',
                     '555-555-5555', '666-666-6666', '777-777-7777', '888-888-8888'],
    'Email': ['nihar@masscoders.tech', 'vignesh@masscoders.tech', 'maheshwar@masscoders.tech', 'naman@masscoders.tech',
              'naveen@masscoders.tech', 'shreya@masscoders.tech', 'varsha@masscoders.tech', 'varun@masscoders.tech'],
    'Address': ['123, MG Road, Bangalore', '456, Brigade Road, Chennai', '789, Rajaji Nagar, Mumbai', '101, Indira Nagar, Delhi',
                '202, Koramangala, Hyderabad', '303, JP Nagar, Kolkata', '404, Electronic City, Pune', '505, HSR Layout, Ahmedabad'],
    'Blood Group': ['A+', 'B-', 'O+', 'AB+', 'A-', 'B+', 'O-', 'AB-']
}

# Create DataFrame
team_mass_coders_df = pd.DataFrame(data)

# Display DataFrame
team_mass_coders_df.head()
# Out:
#               Name               Role  Phone Number  \
# 0  Dodagatta Nihar            Founder  111-111-1111
# 1          Vignesh     Growth Manager  222-222-2222
# 2        Maheshwar  Community Manager  333-333-3333
# 3            Naman  Community Manager  444-444-4444
# 4           Naveen  Community Manager  555-555-5555
#
#                        Email                      Address Blood Group
# 0      nihar@masscoders.tech      123, MG Road, Bangalore          A+
# 1    vignesh@masscoders.tech   456, Brigade Road, Chennai          B-
# 2  maheshwar@masscoders.tech    789, Rajaji Nagar, Mumbai          O+
# 3      naman@masscoders.tech     101, Indira Nagar, Delhi         AB+
# 4     naveen@masscoders.tech  202, Koramangala, Hyderabad          A-

# %%
team_mass_coders_df
# Out:
#               Name                      Role  Phone Number  \
# 0  Dodagatta Nihar                   Founder  111-111-1111
# 1          Vignesh            Growth Manager  222-222-2222
# 2        Maheshwar         Community Manager  333-333-3333
# 3            Naman         Community Manager  444-444-4444
# 4           Naveen         Community Manager  555-555-5555
# 5           Shreya           Course Designer  666-666-6666
# 6           Varsha           Course Designer  777-777-7777
# 7            Varun  Public Relations Manager  888-888-8888
#
#                        Email                      Address Blood Group
# 0      nihar@masscoders.tech      123, MG Road, Bangalore          A+
# 1    vignesh@masscoders.tech   456, Brigade Road, Chennai          B-
# 2  maheshwar@masscoders.tech    789, Rajaji Nagar, Mumbai          O+
# 3      naman@masscoders.tech     101, Indira Nagar, Delhi         AB+
# 4     naveen@masscoders.tech  202, Koramangala, Hyderabad          A-
# 5     shreya@masscoders.tech       303, JP Nagar, Kolkata          B+
# 6     varsha@masscoders.tech   404, Electronic City, Pune          O-
# 7      varun@masscoders.tech   505, HSR Layout, Ahmedabad         AB-

# %% [markdown]
# # Merging Data Frames

# %%
# Team roles data
roles_data = {
    'Name': ['Dodagatta Nihar', 'Vignesh', 'Maheshwar', 'Naman', 'Naveen', 'Shreya', 'Varsha', 'Varun'],
    'Role': ['Founder', 'Growth Manager', 'Community Manager', 'Community Manager', 'Community Manager',
             'Course Designer', 'Course Designer', 'Public Relations Manager']
}

roles_df = pd.DataFrame(roles_data)

# Contact information data
contact_data = {
    'Name': ['Dodagatta Nihar', 'Vignesh', 'Maheshwar', 'Naman', 'Naveen', 'Shreya', 'Varsha', 'Varun'],
    'Phone Number': ['111-111-1111', '222-222-2222', '333-333-3333', '444-444-4444',
                     '555-555-5555', '666-666-6666', '777-777-7777', '888-888-8888'],
    'Email': ['nihar@masscoders.tech', 'vignesh@masscoders.tech', 'maheshwar@masscoders.tech', 'naman@masscoders.tech',
              'naveen@masscoders.tech', 'shreya@masscoders.tech', 'varsha@masscoders.tech', 'varun@masscoders.tech']
}

contact_df = pd.DataFrame(contact_data)

# %%
merged_df = pd.merge(roles_df, contact_df, on='Name')

# %%
merged_df
# Out:
#               Name                      Role  Phone Number  \
# 0  Dodagatta Nihar                   Founder  111-111-1111
# 1          Vignesh            Growth Manager  222-222-2222
# 2        Maheshwar         Community Manager  333-333-3333
# 3            Naman         Community Manager  444-444-4444
# 4           Naveen         Community Manager  555-555-5555
# 5           Shreya           Course Designer  666-666-6666
# 6           Varsha           Course Designer  777-777-7777
# 7            Varun  Public Relations Manager  888-888-8888
#
#                        Email
# 0      nihar@masscoders.tech
# 1    vignesh@masscoders.tech
# 2  maheshwar@masscoders.tech
# 3      naman@masscoders.tech
# 4     naveen@masscoders.tech
# 5     shreya@masscoders.tech
# 6     varsha@masscoders.tech
# 7      varun@masscoders.tech

# %% [markdown]
# # **Importing Dataset**
#
# Importing datasets into Pandas is straightforward, and Pandas supports various file formats like csv, xlsx, json, sql etc.

# %%
df = pd.read_csv('filmtv_movies.csv')

# Display the first few rows of the DataFrame to understand its structure and contents
df.head()
# Out:
#    filmtv_id                                        title  year      genre  \
# 0          2  Bugs Bunny's Third Movie: 1001 Rabbit Tales  1982  Animation
# 1          3                    18 anni tra una settimana  1991      Drama
# 2         17                             Ride a Wild Pony  1976   Romantic
# 3         18                                        Diner  1982     Comedy
# 4         20              A che servono questi quattrini?  1942     Comedy
#
#    duration        country                             directors  \
# 0        76  United States  David Detiege, Art Davis, Bill Perez
# 1        98          Italy                         Luigi Perelli
# 2        91  United States                           Don Chaffey
# 3        95  United States                        Barry Levinson
# 4        85          Italy                        Esodo Pratelli
#
#                                               actors  avg_vote  critics_vote  \
# 0                                                NaN       7.7          8.00
# 1  Kim Rossi Stuart, Simona Cavallari, Ennio Fant...       6.5          6.00
# 2  Michael Craig, John Meillon, Eva Griffith, Gra...       5.7          6.00
# 3  Mickey Rourke, Steve Guttenberg, Ellen Barkin,...       7.0          8.00
# 4  Eduardo De Filippo, Peppino De Filippo, Clelia...       5.9          5.33
#
#    public_vote  total_votes  \
# 0          7.0           22
# 1          7.0            4
# 2          5.0           10
# 3          6.0           18
# 4          7.0           15
#
#                                          description  \
# 0  With two protruding front teeth, a slightly sl...
# 1  Samantha, not yet eighteen, leaves the comfort...
# 2  In the Australia of the pioneers, a boy and a ...
# 3  Five boys from Baltimore have a habit of meeti...
# 4  With a stratagem, the penniless and somewhat p...
#
#                                                notes  humor  rhythm  effort  \
# 0  These are many small independent stories, whic...      3       3       0
# 1  Luigi Perelli, the director of the "Piovra", o...      0       2       0
# 2  "Ecological" story with a happy ending, not wi...      1       2       1
# 3  A cast of will be famous for Levinson's direct...      2       2       0
# 4  Taken from the play by Armando Curcio that the...      3       1       1
#
#    tension  erotism
# 0        0        0
# 1        2        0
# 2        0        0
# 3        1        2
# 4        0        0

# %% [markdown]
# The dataset contains information about movies, represented in a DataFrame structure.
#
# **filmtv_id:** A unique identifier for each movie.
#
# **title:** The title of the movie.
#
# **year:** The release year of the movie.
#
# **genre:** The genre of the movie.
#
# **duration:** The duration of the movie in minutes.
#
# **country:** The country where the movie was produced.
#
# **directors:** Names of the directors of the movie.
#
# **actors:** Names of the main actors in the movie.
#
# **avg_vote, critics_vote, public_vote:** Average ratings from different sources.
#
# **total_votes:** Total number of votes the movie received.
#
# **description:** A short description of the movie plot.
#
# **notes:** Additional notes or commentary about the movie.
#
# **humor, rhythm, effort, tension, erotism:** Various attributes rated on a scale (probably from 0 to a maximum value, representing different aspects of the movie).

# %% [markdown]
# # **Pandas - DataFrame**

# %% [markdown]
# # Properties of DataFrame

# %% [markdown]
# **df.head(n):**
# The df.head(n) method is used to view the first n rows of the DataFrame. This is particularly useful for getting a quick snapshot of the data, especially to understand the structure and the types of data contained in each column. If you don't specify n, the default number of rows displayed is 5.

# %%
df.head(10)  # Displays the first 10 rows of the DataFrame
# Out:
#    filmtv_id                                        title  year      genre  \
# 0          2  Bugs Bunny's Third Movie: 1001 Rabbit Tales  1982  Animation
# 1          3                    18 anni tra una settimana  1991      Drama
# 2         17                             Ride a Wild Pony  1976   Romantic
# 3         18                                        Diner  1982     Comedy
# 4         20              A che servono questi quattrini?  1942     Comedy
# 5         21                       The Uranian Conspiracy  1978        Spy
# 6         22                            A ciascuno il suo  1967      Drama
# 7         23                                    Dead-Bang  1989      Crime
# 8         24                          A... come assassino  1966   Thriller
# 9         26                               At Close Range  1986      Drama
#
#    duration                 country                             directors  \
# 0        76           United States  David Detiege, Art Davis, Bill Perez
# 1        98                   Italy                         Luigi Perelli
# 2        91           United States                           Don Chaffey
# 3        95           United States                        Barry Levinson
# 4        85                   Italy                        Esodo Pratelli
# 5       117  Italy, Germany, Israel  Gianfranco Baldanello, Menahem Golan
# 6        93                   Italy                            Elio Petri
# 7       109           United States                    John Frankenheimer
# 8        80                   Italy          Ray Morrison (Angelo Dorigo)
# 9       115           United States                           James Foley
#
#                                               actors  avg_vote  critics_vote  \
# 0                                                NaN       7.7          8.00
# 1  Kim Rossi Stuart, Simona Cavallari, Ennio Fant...       6.5          6.00
# 2  Michael Craig, John Meillon, Eva Griffith, Gra...       5.7          6.00
# 3  Mickey Rourke, Steve Guttenberg, Ellen Barkin,...       7.0          8.00
# 4  Eduardo De Filippo, Peppino De Filippo, Clelia...       5.9          5.33
# 5  Fabio Testi, Janet Agren, Assaf Dayan, Siegfri...       4.8          3.50
# 6  Gian Maria Volonté, Irene Papas, Gabriele Ferz...       7.6          7.68
# 7  Don Johnson, Penelope Ann Miller, William Fors...       6.0          6.00
# 8  Alan Steel, Mary Arden, Sergio Ciani, Ivano Da...       5.2          3.00
# 9  Christopher Walken, Sean Penn, Chris Penn, Mar...       7.5          7.64
#
#    public_vote  total_votes  \
# 0          7.0           22
# 1          7.0            4
# 2          5.0           10
# 3          6.0           18
# 4          7.0           15
# 5          6.0            5
# 6          7.0          139
# 7          6.0           27
# 8          7.0            5
# 9          7.0           90
#
#                                          description  \
# 0  With two protruding front teeth, a slightly sl...
# 1  Samantha, not yet eighteen, leaves the comfort...
# 2  In the Australia of the pioneers, a boy and a ...
# 3  Five boys from Baltimore have a habit of meeti...
# 4  With a stratagem, the penniless and somewhat p...
# 5  Two Israeli secret agents discover that traffi...
# 6  Investigations into two murders committed in a...
# 7  In the throes of a double murder, Jerry Beck, ...
# 8  After a man's corpse is found by his niece in ...
# 9  Young Brad (Penn) lives with his grandmother a...
#
#                                                notes  humor  rhythm  effort  \
# 0  These are many small independent stories, whic...      3       3       0
# 1  Luigi Perelli, the director of the "Piovra", o...      0       2       0
# 2  "Ecological" story with a happy ending, not wi...      1       2       1
# 3  A cast of will be famous for Levinson's direct...      2       2       0
# 4  Taken from the play by Armando Curcio that the...      3       1       1
# 5  Action and chases for half of Europe, espionag...      1       2       0
# 6  Champion of the cinema of civil commitment, El...      0       2       3
# 7  When it comes to talking about mysterious plot...      0       2       0
# 8             Approximation and mediocrity in go-go.      1       2       0
# 9  Powerful and brutal thriller, second work by J...      1       3       2
#
#    tension  erotism
# 0        0        0
# 1        2        0
# 2        0        0
# 3        1        2
# 4        0        0
# 5        2        0
# 6        3        1
# 7        2        1
# 8        1        0
# 9        4        2

# %% [markdown]
# **df.tail(n):**
# The df.tail(n) method is similar to df.head(n) but for the end of the DataFrame. It returns the last n rows. This is useful to see the most recent or the last few entries in your data, depending on the ordering of your dataset. Like df.head(n), the default value of n is 5 if it isn't specified.

# %%
df.tail(10)  # Displays the last 10 rows of the DataFrame
# Out:
#        filmtv_id                      title  year      genre  duration  \
# 41389     232184                    Nowhere  2023   Thriller       109
# 41390     232203     Mes petites amoureuses  1974      Drama       123
# 41391     232755                Organ Trail  2023    Western       112
# 41392     232757      Hidden Family Secrets  2021   Thriller        87
# 41393     232816       La stoccata vincente  2023  Biography       107
# 41394     232817         Gold Digger Killer  2021   Thriller        87
# 41395     232893        Addio al nubilato 2  2023     Comedy        90
# 41396     232915                Konferensen  2023     Horror       100
# 41397     232919                  Ballelina  2023   Thriller        92
# 41398     232920  Invitación a un Asesinato  2023   Thriller        92
#
#                      country             directors  \
# 41389                  Spain          Albert Pintó
# 41390                 France         Jean Eustache
# 41391          United States  Michael Patrick Jann
# 41392                 Canada        Stefan Brogren
# 41393                  Italy      Nicola Campiotti
# 41394  Canada, United States            Robin Hays
# 41395                  Italy    Francesco Apolloni
# 41396                 Sweden         Patrik Eklund
# 41397            South Korea        Chung-Hyun Lee
# 41398                 Mexico          J.M Cravioto
#
#                                                   actors  avg_vote  \
# 41389                         Anna Castillo, Tamar Novas       5.3
# 41390  Martin Loeb, Jacqueline Dufranne, Jacques Roma...       8.3
# 41391  Zoé De Grand Maison, Mather Zickel, Lisa LoCic...       5.0
# 41392  Alex Paxton-Beesley, Madelyn Keys, Sonja Smits...       5.3
# 41393  Alessio Vassallo, Flavio Insinna, Elena Funari...       4.5
# 41394  Julie Benz, Roan Curtis, Georgia Bradner, Eli ...       4.0
# 41395  Laura Chiatti, Chiara Francini, Antonia Liskov...       2.7
# 41396  Katia Winter, Eva Melander, Lola Zackow, Adam ...       6.0
# 41397             Jeon Jong-seo, Park Yu-rim, Ji-hun Kim       5.8
# 41398  Maribel Verdú, Stephanie Cayo, Manolo Cardona,...       6.0
#
#        critics_vote  public_vote  total_votes  \
# 41389          5.25          5.0           10
# 41390          8.50          8.0            3
# 41391          5.50          5.0            8
# 41392           NaN          5.0            3
# 41393           NaN          5.0            4
# 41394           NaN          4.0            3
# 41395           NaN          3.0            3
# 41396           NaN          6.0            6
# 41397           NaN          6.0            5
# 41398           NaN          6.0            3
#
#                                              description  \
# 41389  Mia, pregnant, flees together with her husband...
# 41390  Daniel is a silent boy who observes girls with...
# 41391  The young abigale Archer is located alone in M...
# 41392  While struggling to try to save her daughter, ...
# 41393  The true story of the prodigy of fencing Paolo...
# 41394  Celeste is an attractive waitress in the forti...
# 41395  When Eleonora is downloaded to the altar, her ...
# 41396  A team building conference organized for a gro...
# 41397  Once Ok-Ju worked as a bodyguard and was one o...
# 41398  A great passionate of crime stories is trapped...
#
#                                                    notes  humor  rhythm  \
# 41389                                                NaN      0       0
# 41390                                                NaN      0       0
# 41391                                                NaN      0       0
# 41392                                                NaN      0       0
# 41393  Freely inspired by the book The winning fool b...      0       0
# 41394                    Freely taken from a true story.      0       0
# 41395                   Bachelorette fare sequel (2021).      0       0
# 41396                                                NaN      0       0
# 41397                                                NaN      0       0
# 41398                                                NaN      0       0
#
#        effort  tension  erotism
# 41389       0        0        0
# 41390       0        0        0
# 41391       0        0        0
# 41392       0        0        0
# 41393       0        0        0
# 41394       0        0        0
# 41395       0        0        0
# 41396       0        0        0
# 41397       0        0        0
# 41398       0        0        0

# %% [markdown]
# **df.shape:**
# The df.shape attribute of a DataFrame returns a tuple representing the dimensionality of the DataFrame. The first element of the tuple is the number of rows, and the second is the number of columns. This is useful when you need to know how large the dataset is, such as when you are preprocessing data or ensuring that data manipulations have executed correctly.

# %%
df.shape  # Outputs: (number of rows, number of columns)
# Out:
# (41399, 19)

# %% [markdown]
# **df.columns:**
# The df.columns attribute returns an Index object containing the column labels of the DataFrame. Knowing the column names is essential for accessing specific data in the DataFrame, performing analyses, and for data manipulation tasks like sorting, filtering, or applying functions to certain columns.

# %%
df.columns  # Lists all the column names in the DataFrame
# Out:
# Index(['filmtv_id', 'title', 'year', 'genre', 'duration', 'country',
#        'directors', 'actors', 'avg_vote', 'critics_vote', 'public_vote',
#        'total_votes', 'description', 'notes', 'humor', 'rhythm', 'effort',
#        'tension', 'erotism'],
#       dtype='object')

# %% [markdown]
# **Inspecting Data Types:** Each column in a DataFrame has a specific data type. Understanding these types is crucial for proper data manipulation

# %%
# Display the data types of each column
df.dtypes
# Out:
# filmtv_id         int64
# title            object
# year              int64
# genre            object
# duration          int64
# country          object
# directors        object
# actors           object
# avg_vote        float64
# critics_vote    float64
# public_vote     float64
# total_votes       int64
# description      object
# notes            object
# humor             int64
# rhythm            int64
# effort            int64
# tension           int64
# erotism           int64
# dtype: object

# %% [markdown]
# **Summary Statistics:** For numerical data, it's useful to get a sense of their central tendency and spread

# %%
# Display summary statistics for numerical columns
df.describe()
# Out:
#            filmtv_id          year      duration      avg_vote  critics_vote  \
# count   41399.000000  41399.000000  41399.000000  41399.000000  36703.000000
# mean    57746.410179   1993.505302    100.537163      5.801522      5.796077
# std     59962.095730     23.685612     27.260962      1.403861      1.593062
# min         2.000000   1897.000000     41.000000      1.000000      1.000000
# 25%     15857.000000   1976.000000     90.000000      4.800000      4.670000
# 50%     36266.000000   2001.000000     96.000000      5.900000      6.000000
# 75%     70935.000000   2013.000000    107.000000      6.900000      7.000000
# max    232920.000000   2023.000000   1525.000000     10.000000     10.000000
#
#         public_vote   total_votes         humor        rhythm        effort  \
# count  41205.000000  41399.000000  41399.000000  41399.000000  41399.000000
# mean       5.924135     36.986763      0.577381      1.345347      0.684847
# std        1.480112     69.386853      0.899402      1.154829      1.112334
# min        1.000000      1.000000      0.000000      0.000000      0.000000
# 25%        5.000000      5.000000      0.000000      0.000000      0.000000
# 50%        6.000000     12.000000      0.000000      2.000000      0.000000
# 75%        7.000000     36.000000      1.000000      2.000000      1.000000
# max       10.000000   1082.000000      5.000000      5.000000      5.000000
#
#             tension       erotism
# count  41399.000000  41399.000000
# mean       0.919153      0.309814
# std        1.095410      0.645930
# min        0.000000      0.000000
# 25%        0.000000      0.000000
# 50%        0.000000      0.000000
# 75%        2.000000      0.000000
# max        5.000000      5.000000

# %% [markdown]
# # Accessing and Filtering:

# %% [markdown]
# **df.loc:**
# The df.loc method is used for label-based indexing, meaning you can access rows and columns using their labels (i.e., index names and column names). It allows for selecting a subset of rows and columns from a DataFrame with powerful and flexible slicing, indexing, and filtering options.

# %%
df.head(5)
# Out:
#    filmtv_id                                        title  year      genre  \
# 0          2  Bugs Bunny's Third Movie: 1001 Rabbit Tales  1982  Animation
# 1          3                    18 anni tra una settimana  1991      Drama
# 2         17                             Ride a Wild Pony  1976   Romantic
# 3         18                                        Diner  1982     Comedy
# 4         20              A che servono questi quattrini?  1942     Comedy
#
#    duration        country                             directors  \
# 0        76  United States  David Detiege, Art Davis, Bill Perez
# 1        98          Italy                         Luigi Perelli
# 2        91  United States                           Don Chaffey
# 3        95  United States                        Barry Levinson
# 4        85          Italy                        Esodo Pratelli
#
#                                               actors  avg_vote  critics_vote  \
# 0                                                NaN       7.7          8.00
# 1  Kim Rossi Stuart, Simona Cavallari, Ennio Fant...       6.5          6.00
# 2  Michael Craig, John Meillon, Eva Griffith, Gra...       5.7          6.00
# 3  Mickey Rourke, Steve Guttenberg, Ellen Barkin,...       7.0          8.00
# 4  Eduardo De Filippo, Peppino De Filippo, Clelia...       5.9          5.33
#
#    public_vote  total_votes  \
# 0          7.0           22
# 1          7.0            4
# 2          5.0           10
# 3          6.0           18
# 4          7.0           15
#
#                                          description  \
# 0  With two protruding front teeth, a slightly sl...
# 1  Samantha, not yet eighteen, leaves the comfort...
# 2  In the Australia of the pioneers, a boy and a ...
# 3  Five boys from Baltimore have a habit of meeti...
# 4  With a stratagem, the penniless and somewhat p...
#
#                                                notes  humor  rhythm  effort  \
# 0  These are many small independent stories, whic...      3       3       0
# 1  Luigi Perelli, the director of the "Piovra", o...      0       2       0
# 2  "Ecological" story with a happy ending, not wi...      1       2       1
# 3  A cast of will be famous for Levinson's direct...      2       2       0
# 4  Taken from the play by Armando Curcio that the...      3       1       1
#
#    tension  erotism
# 0        0        0
# 1        2        0
# 2        0        0
# 3        1        2
# 4        0        0

# %%
# Selecting all rows and a specific column by label
titles = df.loc[:, 'title']
titles
# Out:
# 0        Bugs Bunny's Third Movie: 1001 Rabbit Tales
# 1                          18 anni tra una settimana
# 2                                   Ride a Wild Pony
# 3                                              Diner
# 4                    A che servono questi quattrini?
#                             ...
# 41394                             Gold Digger Killer
# 41395                            Addio al nubilato 2
# 41396                                    Konferensen
# 41397                                      Ballelina
# 41398                      Invitación a un Asesinato
# Name: title, Length: 41399, dtype: object

# %%
# Selecting a range of rows and multiple columns by labels
subset = df.loc[10:20, ['title', 'year', 'genre']]
subset
# Out:
#                                    title  year        genre
# 10             A Ghentar si muore facile  1968    Adventure
# 11               Sleeping with the Enemy  1990        Drama
# 12                   In Bed With Madonna  1990  Documentary
# 13                    Bowery at Midnight  1942       Horror
# 14  A mezzanotte va la ronda del piacere  1975       Comedy
# 15                          Mr. Majestyk  1974       Action
# 16                          Warning Sign  1985       Action
# 17                      About Last Night  1986       Comedy
# 18                             Fail-Safe  1964        Drama
# 19                      Some Like It Hot  1959       Comedy
# 20                    A qualsiasi prezzo  1968    Adventure

# %%
# Conditional selection using a boolean array
dramas = df.loc[df['genre'] == 'Drama']
dramas
# Out:
#        filmtv_id                      title  year  genre  duration  \
# 1              3  18 anni tra una settimana  1991  Drama        98
# 6             22          A ciascuno il suo  1967  Drama        93
# 9             26             At Close Range  1986  Drama       115
# 11            32    Sleeping with the Enemy  1990  Drama        96
# 18            49                  Fail-Safe  1964  Drama       110
# ...          ...                        ...   ...    ...       ...
# 41368     229838           Tereddüt Çizgisi  2023  Drama        84
# 41370     229865                     Stolen  2023  Drama        92
# 41371     229881                       Árni  2023  Drama       103
# 41372     229883              Kanata no uta  2023  Drama        84
# 41390     232203     Mes petites amoureuses  1974  Drama       123
#
#                               country      directors  \
# 1                               Italy  Luigi Perelli
# 6                               Italy     Elio Petri
# 9                       United States    James Foley
# 11                      United States   Joseph Ruben
# 18                      United States   Sidney Lumet
# ...                               ...            ...
# 41368  Turkey, France, Romania, Spain   Selman Nacar
# 41370                           India   Karan Tejpal
# 41371                         Hungary   Dorka Vermes
# 41372                           Japan  Kyoshi Sugita
# 41390                          France  Jean Eustache
#
#                                                   actors  avg_vote  \
# 1      Kim Rossi Stuart, Simona Cavallari, Ennio Fant...       6.5
# 6      Gian Maria Volonté, Irene Papas, Gabriele Ferz...       7.6
# 9      Christopher Walken, Sean Penn, Chris Penn, Mar...       7.5
# 11     Julia Roberts, Patrick Bergin, Kevin Anderson,...       5.0
# 18     Henry Fonda, Dan O'Herlihy, Walter Matthau, Do...       8.2
# ...                                                  ...       ...
# 41368                            Tülin Özen, Görkem Ipek       7.0
# 41370  Abhishek Banerjee, Harish Khanna, Mia Maelzer,...       5.3
# 41371                       Péter Turi, Andrea Spolarics       5.3
# 41372          An Ogawa, Yûko Nakamura, Hidekazu Mashima       5.5
# 41390  Martin Loeb, Jacqueline Dufranne, Jacques Roma...       8.3
#
#        critics_vote  public_vote  total_votes  \
# 1              6.00          7.0            4
# 6              7.68          7.0          139
# 9              7.64          7.0           90
# 11             4.33          6.0          111
# 18             8.20          8.0           73
# ...             ...          ...          ...
# 41368          7.00          7.0            3
# 41370          6.00          5.0            4
# 41371          6.00          5.0            3
# 41372          5.00          6.0            3
# 41390          8.50          8.0            3
#
#                                              description  \
# 1      Samantha, not yet eighteen, leaves the comfort...
# 6      Investigations into two murders committed in a...
# 9      Young Brad (Penn) lives with his grandmother a...
# 11     Martin and Laura Burney have been married for ...
# 18     When the US strategic air command is alerted t...
# ...                                                  ...
# 41368  All over a day. A criminal lawyer is awaiting ...
# 41370  The five -month daughter of Jhumpa Mahato, poo...
# 41371  A lone nomad who works for an itinerant circus...
# 41372  The twenty -five year old Haru, committed in a...
# 41390  Daniel is a silent boy who observes girls with...
#
#                                                    notes  humor  rhythm  \
# 1      Luigi Perelli, the director of the "Piovra", o...      0       2
# 6      Champion of the cinema of civil commitment, El...      0       2
# 9      Powerful and brutal thriller, second work by J...      1       3
# 11     Some twist is actually well placed, but from a...      1       3
# 18     With this film Lumet returns great, after a pe...      0       3
# ...                                                  ...    ...     ...
# 41368                                                NaN      0       0
# 41370                                                NaN      0       0
# 41371                                                NaN      0       0
# 41372                                                NaN      0       0
# 41390                                                NaN      0       0
#
#        effort  tension  erotism
# 1           0        2        0
# 6           3        3        1
# 9           2        4        2
# 11          2        3        1
# 18          3        3        0
# ...       ...      ...      ...
# 41368       0        0        0
# 41370       0        0        0
# 41371       0        0        0
# 41372       0        0        0
# 41390       0        0        0
#
# [12003 rows x 19 columns]

# %%
multiple_condition = df.loc[(df['genre'] == 'Drama') & (df['avg_vote']>7.0)]
multiple_condition
# Out:
#        filmtv_id                     title  year  genre  duration  \
# 6             22         A ciascuno il suo  1967  Drama        93
# 9             26            At Close Range  1986  Drama       115
# 18            49                 Fail-Safe  1964  Drama       110
# 30            70  Can You Feel Me Dancing?  1986  Drama       120
# 44            92                 Accattone  1961  Drama       120
# ...          ...                       ...   ...    ...       ...
# 41320     226639                Sambizanga  1972  Drama        97
# 41349     229784                The Burial  2023  Drama       126
# 41355     229808      Aku wa sonzai shinai  2023  Drama       106
# 41366     229832       Magyarázat mindenre  2023  Drama       151
# 41390     232203    Mes petites amoureuses  1974  Drama       123
#
#                  country            directors  \
# 6                  Italy           Elio Petri
# 9          United States          James Foley
# 18         United States         Sidney Lumet
# 30         United States       Michael Miller
# 44                 Italy  Pier Paolo Pasolini
# ...                  ...                  ...
# 41320     Angola, France       Sarah Maldoror
# 41349      United States         Maggie Betts
# 41355              Japan    Ryûsuke Hamaguchi
# 41366  Hungary, Slovakia          Gábor Reisz
# 41390             France        Jean Eustache
#
#                                                   actors  avg_vote  \
# 6      Gian Maria Volonté, Irene Papas, Gabriele Ferz...       7.6
# 9      Christopher Walken, Sean Penn, Chris Penn, Mar...       7.5
# 18     Henry Fonda, Dan O'Herlihy, Walter Matthau, Do...       8.2
# 30     Justine Bateman, Jason Bateman, Max Gail, Joe ...       8.0
# 44     Franco Citti, Franca Pasut, Adriana Asti, Paol...       8.4
# ...                                                  ...       ...
# 41320  Elisa Andrade, Jean M'Vondo, Dino Abelino, Ben...       7.5
# 41349  Bill Camp, Jamie Foxx, Tommy Lee Jones, Alan R...       7.3
# 41355  Hitoshi Omika, Ryo Nishikawa, Ryuji Kosaka, Ay...       7.2
# 41366  Adonyi-Walsh Gáspár, István Znamenák, András R...       7.3
# 41390  Martin Loeb, Jacqueline Dufranne, Jacques Roma...       8.3
#
#        critics_vote  public_vote  total_votes  \
# 6              7.68          7.0          139
# 9              7.64          7.0           90
# 18             8.20          8.0           73
# 30             6.00         10.0            3
# 44             8.81          8.0          299
# ...             ...          ...          ...
# 41320          7.50          8.0            4
# 41349           NaN          7.0           10
# 41355          7.00          7.0            9
# 41366          7.33          7.0            6
# 41390          8.50          8.0            3
#
#                                              description  \
# 6      Investigations into two murders committed in a...
# 9      Young Brad (Penn) lives with his grandmother a...
# 18     When the US strategic air command is alerted t...
# 30     Karin Nichols, blind since birth, no longer st...
# 44     Story of a drifter, Accattone, who drags an em...
# ...                                                  ...
# 41320  Angola, 1961. Domingos Xavier, an anti -coloni...
# 41349  With the help of two lawyers, a family struggl...
# 41355  Takumi and his daughter Hana live in Mizubiki,...
# 41366  A realistic portrait of a divided country, Hun...
# 41390  Daniel is a silent boy who observes girls with...
#
#                                                    notes  humor  rhythm  \
# 6      Champion of the cinema of civil commitment, El...      0       2
# 9      Powerful and brutal thriller, second work by J...      1       3
# 18     With this film Lumet returns great, after a pe...      0       3
# 30     Based on a true story, it is a film for televi...      0       2
# 44     After seeing the first dailies Federico Fellin...      1       3
# ...                                                  ...    ...     ...
# 41320  Taken from a true story told in the book in Vi...      0       0
# 41349                                                NaN      0       1
# 41355                                                NaN      0       0
# 41366                                                NaN      0       0
# 41390                                                NaN      0       0
#
#        effort  tension  erotism
# 6           3        3        1
# 9           2        4        2
# 18          3        3        0
# 30          2        0        0
# 44          3        3        2
# ...       ...      ...      ...
# 41320       0        0        0
# 41349       1        1        0
# 41355       0        0        0
# 41366       0        0        0
# 41390       0        0        0
#
# [3649 rows x 19 columns]

# %% [markdown]
# **df.iloc:**
# While df.loc uses labels for indexing, df.iloc allows for integer-based indexing. You use df.iloc to access rows and columns by their integer positions, which makes it useful when you need to access data by its position in the DataFrame.

# %%
df.head(5)
# Out:
#    filmtv_id                                        title  year      genre  \
# 0          2  Bugs Bunny's Third Movie: 1001 Rabbit Tales  1982  Animation
# 1          3                    18 anni tra una settimana  1991      Drama
# 2         17                             Ride a Wild Pony  1976   Romantic
# 3         18                                        Diner  1982     Comedy
# 4         20              A che servono questi quattrini?  1942     Comedy
#
#    duration        country                             directors  \
# 0        76  United States  David Detiege, Art Davis, Bill Perez
# 1        98          Italy                         Luigi Perelli
# 2        91  United States                           Don Chaffey
# 3        95  United States                        Barry Levinson
# 4        85          Italy                        Esodo Pratelli
#
#                                               actors  avg_vote  critics_vote  \
# 0                                                NaN       7.7          8.00
# 1  Kim Rossi Stuart, Simona Cavallari, Ennio Fant...       6.5          6.00
# 2  Michael Craig, John Meillon, Eva Griffith, Gra...       5.7          6.00
# 3  Mickey Rourke, Steve Guttenberg, Ellen Barkin,...       7.0          8.00
# 4  Eduardo De Filippo, Peppino De Filippo, Clelia...       5.9          5.33
#
#    public_vote  total_votes  \
# 0          7.0           22
# 1          7.0            4
# 2          5.0           10
# 3          6.0           18
# 4          7.0           15
#
#                                          description  \
# 0  With two protruding front teeth, a slightly sl...
# 1  Samantha, not yet eighteen, leaves the comfort...
# 2  In the Australia of the pioneers, a boy and a ...
# 3  Five boys from Baltimore have a habit of meeti...
# 4  With a stratagem, the penniless and somewhat p...
#
#                                                notes  humor  rhythm  effort  \
# 0  These are many small independent stories, whic...      3       3       0
# 1  Luigi Perelli, the director of the "Piovra", o...      0       2       0
# 2  "Ecological" story with a happy ending, not wi...      1       2       1
# 3  A cast of will be famous for Levinson's direct...      2       2       0
# 4  Taken from the play by Armando Curcio that the...      3       1       1
#
#    tension  erotism
# 0        0        0
# 1        2        0
# 2        0        0
# 3        1        2
# 4        0        0

# %%
# Selecting a single row from the DataFrame
single_row = df.iloc[0]
single_row
# Out:
# filmtv_id                                                       2
# title                 Bugs Bunny's Third Movie: 1001 Rabbit Tales
# year                                                         1982
# genre                                                   Animation
# duration                                                       76
# country                                             United States
# directors                    David Detiege, Art Davis, Bill Perez
# actors                                                        NaN
# avg_vote                                                      7.7
# critics_vote                                                  8.0
# public_vote                                                   7.0
# total_votes                                                    22
# description     With two protruding front teeth, a slightly sl...
# notes           These are many small independent stories, whic...
# humor                                                           3
# rhythm                                                          3
# effort                                                          0
# tension                                                         0
# erotism                                                         0
# Name: 0, dtype: object

# %%
# Selecting a specific row and columns by integer indices
specific_data = df.iloc[10, [1, 2, 3]]  # row at index 10 and columns at indices 1, 2, and 3
specific_data
# Out:
# title    A Ghentar si muore facile
# year                          1968
# genre                    Adventure
# Name: 10, dtype: object

# %%
# Slicing to get multiple rows and columns
multi_slice = df.iloc[10:15, 0:4]  # Rows 10 to 14 and columns 0 to 3
multi_slice
# Out:
#     filmtv_id                                 title  year        genre
# 10         30             A Ghentar si muore facile  1968    Adventure
# 11         32               Sleeping with the Enemy  1990        Drama
# 12         34                   In Bed With Madonna  1990  Documentary
# 13         36                    Bowery at Midnight  1942       Horror
# 14         37  A mezzanotte va la ronda del piacere  1975       Comedy

# %% [markdown]
# **df.at:**
# df.at is designed to access a single value for a row/column label pair. It is very similar to df.loc for accessing scalar values but is optimized for faster access when you only need to get or set a single value in a DataFrame.

# %%
# Access a specific single value using row label and column name
title_of_first_movie = df.at[0, 'title']
title_of_first_movie
# Out:
# "Bugs Bunny's Third Movie: 1001 Rabbit Tales"

# %% [markdown]
# **Filtering Based on Criteria:**
# Filtering data based on specific criteria is a common operation in data analysis. Pandas provides several methods to perform these operations, often using boolean indexing.

# %%
# Filter movies released after 2010
recent_movies = df[df['year'] > 2010]
recent_movies
# Out:
#        filmtv_id                      title  year      genre  duration  \
# 22817      39955           The Tree of Life  2011      Drama       138
# 23725      41448        Season of the Witch  2011  Adventure        95
# 24186      42398                   Restless  2011      Drama        95
# 24426      42847             Qualunquemente  2011  Grotesque        96
# 24427      42848  Una sconfinata giovinezza  2011      Drama        98
# ...          ...                        ...   ...        ...       ...
# 41394     232817         Gold Digger Killer  2021   Thriller        87
# 41395     232893        Addio al nubilato 2  2023     Comedy        90
# 41396     232915                Konferensen  2023     Horror       100
# 41397     232919                  Ballelina  2023   Thriller        92
# 41398     232920  Invitación a un Asesinato  2023   Thriller        92
#
#                      country           directors  \
# 22817          United States     Terrence Malick
# 23725          United States        Dominic Sena
# 24186          United States        Gus Van Sant
# 24426                  Italy  Giulio Manfredonia
# 24427                  Italy          Pupi Avati
# ...                      ...                 ...
# 41394  Canada, United States          Robin Hays
# 41395                  Italy  Francesco Apolloni
# 41396                 Sweden       Patrik Eklund
# 41397            South Korea      Chung-Hyun Lee
# 41398                 Mexico        J.M Cravioto
#
#                                                   actors  avg_vote  \
# 22817  Brad Pitt, Sean Penn, Jessica Chastain, Tye Sh...       7.4
# 23725  Nicolas Cage, Claire Foy, Ron Perlman, Stephen...       4.3
# 24186  Mia Wasikowska, Schuyler Fisk, Jane Adams, Lus...       6.9
# 24426  Antonio Albanese, Sergio Rubini, Lorenza Indov...       5.6
# 24427  Fabrizio Bentivoglio, Francesca Neri, Serena G...       6.7
# ...                                                  ...       ...
# 41394  Julie Benz, Roan Curtis, Georgia Bradner, Eli ...       4.0
# 41395  Laura Chiatti, Chiara Francini, Antonia Liskov...       2.7
# 41396  Katia Winter, Eva Melander, Lola Zackow, Adam ...       6.0
# 41397             Jeon Jong-seo, Park Yu-rim, Ji-hun Kim       5.8
# 41398  Maribel Verdú, Stephanie Cayo, Manolo Cardona,...       6.0
#
#        critics_vote  public_vote  total_votes  \
# 22817          7.43          7.0          476
# 23725          4.13          4.0          153
# 24186          6.59          7.0          151
# 24426          5.65          6.0          291
# 24427          6.60          7.0           95
# ...             ...          ...          ...
# 41394           NaN          4.0            3
# 41395           NaN          3.0            3
# 41396           NaN          6.0            6
# 41397           NaN          6.0            5
# 41398           NaN          6.0            3
#
#                                              description  \
# 22817  Jack, an eleven-year-old boy, lives in the Mid...
# 23725  During the fourteenth century, when the black ...
# 24186  Enoch is a 17-year-old who lost both parents a...
# 24426  Cetto La Qualunque (Albanese) returns to Italy...
# 24427  Lino Settembre and his wife Chicca lead a peac...
# ...                                                  ...
# 41394  Celeste is an attractive waitress in the forti...
# 41395  When Eleonora is downloaded to the altar, her ...
# 41396  A team building conference organized for a gro...
# 41397  Once Ok-Ju worked as a bodyguard and was one o...
# 41398  A great passionate of crime stories is trapped...
#
#                                                    notes  humor  rhythm  \
# 22817  Beauty passes through cinema: the director, as...      0       2
# 23725  Thrown to the wind the attempts to build a bar...      1       2
# 24186  The director of Last Days returns to spy on th...      2       2
# 24426  The grotesque and at times effective mask rema...      4       3
# 24427  Written with the taste of a novelist's plot, i...      2       2
# ...                                                  ...    ...     ...
# 41394                    Freely taken from a true story.      0       0
# 41395                   Bachelorette fare sequel (2021).      0       0
# 41396                                                NaN      0       0
# 41397                                                NaN      0       0
# 41398                                                NaN      0       0
#
#        effort  tension  erotism
# 22817       4        2        0
# 23725       1        3        0
# 24186       3        1        0
# 24426       3        1        1
# 24427       3        2        0
# ...       ...      ...      ...
# 41394       0        0        0
# 41395       0        0        0
# 41396       0        0        0
# 41397       0        0        0
# 41398       0        0        0
#
# [13100 rows x 19 columns]

# %%
# Movies with a high public vote and specific genre
highly_rated_thrillers = df[(df['public_vote'] >= 8) & (df['genre'] == 'Thriller')]
highly_rated_thrillers
# Out:
#        filmtv_id                  title  year     genre  duration  \
# 21            54         Johnny O'Clock  1947  Thriller        95
# 27            67  You'll Like My Mother  1973  Thriller        94
# 140          236      Time Without Pity  1956  Thriller        88
# 183          296   Strangers on a Train  1951  Thriller        96
# 302          478               Gaslight  1944  Thriller       109
# ...          ...                    ...   ...       ...       ...
# 40950     216918              Aru otoko  2022  Thriller       121
# 41118     220183        The Other Child  2022  Thriller       114
# 41200     221403   Anatomie d'une chute  2023  Thriller       151
# 41218     221890                Ming On  2022  Thriller       109
# 41246     223251          Twisted Nerve  1968  Thriller       112
#
#              country         directors  \
# 21     United States     Robert Rossen
# 27     United States    Lamont Johnson
# 140    Great Britain      Joseph Losey
# 183    United States  Alfred Hitchcock
# 302    United States      George Cukor
# ...              ...               ...
# 40950          Japan      Kei Ishikawa
# 41118    South Korea     Jin-young Kim
# 41200         France     Justine Triet
# 41218      Hong Kong        Soi Cheang
# 41246  Great Britain      Roy Boulting
#
#                                                   actors  avg_vote  \
# 21     Dick Powell, Evelyn Keyes, Lee J. Cobb, Ellen ...       7.8
# 27     Patty Duke, Rosemary Murphy, Richard Thomas, S...       7.8
# 140    Michael Redgrave, Ann Todd, Peter Cushing, Joa...       7.9
# 183    Farley Granger, Robert Walker, Ruth Roman, Leo...       8.4
# 302    Ingrid Bergman, Charles Boyer, Joseph Cotten, ...       7.8
# ...                                                  ...       ...
# 40950  Satoshi Tsumabuki, Sakura Andô, Masataka Kubot...       7.3
# 41118                           Kim Min-Jae, Hyo-ju Park       5.3
# 41200  Sandra Hüller, Samuel Theis, Swann Arlaud, Jeh...       7.3
# 41218  Ka-Tung Lam, Charm Man Chan, Wing-Sze Ng, Lok ...       7.8
# 41246  Hayley Mills, Hywel Bennett, Billie Whitelaw, ...       7.5
#
#        critics_vote  public_vote  total_votes  \
# 21             8.00          8.0           20
# 27             8.00          8.0            6
# 140            8.00          8.0           16
# 183            8.66          8.0          258
# 302            7.86          8.0           94
# ...             ...          ...          ...
# 40950          7.00          8.0            3
# 41118          3.00          8.0            3
# 41200          7.00          8.0            4
# 41218          8.00          8.0            4
# 41246          7.00          8.0            3
#
#                                              description  \
# 21     Johnny O'Clock (Powell) is a minority partner ...
# 27     After her husband's death, Francesca decides t...
# 140    Alec Graham was sentenced to death for killing...
# 183    Guy Haines is a successful tennis player with ...
# 302    Paula married Gregory, who long ago strangled ...
# ...                                                  ...
# 40950  Akira works as a lawyer and one day he meets a...
# 41118  The members of a family deeply likes the disap...
# 41200  Samuel is found dead, buried in the snow outsi...
# 41218  A master of fortune teller (Gordon Lam), very ...
# 41246  Martin Durnley (Hywel Bennett) is a twenty yea...
#
#                                                    notes  humor  rhythm  \
# 21     Columbia took advantage of Dick Powell's recen...      1       3
# 27     Specialist Lamont Johnson has built an effecti...      0       3
# 140    Emigrated to Great Britain after being blackli...      0       3
# 183    Patricia Highsmith's first novel, that of the ...      1       2
# 302    Nice "gothic" melodrama by George Cukor. The m...      2       4
# ...                                                  ...    ...     ...
# 40950                                                NaN      0       0
# 41118                                                NaN      0       0
# 41200                                                NaN      0       0
# 41218                                                NaN      0       0
# 41246                                                NaN      0       0
#
#        effort  tension  erotism
# 21          1        3        1
# 27          1        3        0
# 140         2        3        0
# 183         2        4        0
# 302         3        4        2
# ...       ...      ...      ...
# 40950       0        0        0
# 41118       0        0        0
# 41200       0        0        0
# 41218       0        0        0
# 41246       0        0        0
#
# [327 rows x 19 columns]

# %%
# Movies from a specific country
us_movies = df[df['country'] == 'United States']
us_movies
# Out:
#        filmtv_id                                          title  year  \
# 0              2    Bugs Bunny's Third Movie: 1001 Rabbit Tales  1982
# 2             17                               Ride a Wild Pony  1976
# 3             18                                          Diner  1982
# 7             23                                      Dead-Bang  1989
# 9             26                                 At Close Range  1986
# ...          ...                                            ...   ...
# 41377     231044                                        Shelter  2023
# 41382     231556  To End All War: Oppenheimer & the Atomic Bomb  2023
# 41384     232066                                  Hostage House  2021
# 41385     232101                                 Fear the Night  2023
# 41391     232755                                    Organ Trail  2023
#
#              genre  duration        country  \
# 0        Animation        76  United States
# 2         Romantic        91  United States
# 3           Comedy        95  United States
# 7            Crime       109  United States
# 9            Drama       115  United States
# ...            ...       ...            ...
# 41377     Thriller        91  United States
# 41382  Documentary        87  United States
# 41384       Horror        85  United States
# 41385       Horror        92  United States
# 41391      Western       112  United States
#
#                                   directors  \
# 0      David Detiege, Art Davis, Bill Perez
# 2                               Don Chaffey
# 3                            Barry Levinson
# 7                        John Frankenheimer
# 9                               James Foley
# ...                                     ...
# 41377                    Anthony Nardolillo
# 41382                    Christopher Cassel
# 41384                         David Benullo
# 41385                           Neil LaBute
# 41391                  Michael Patrick Jann
#
#                                                   actors  avg_vote  \
# 0                                                    NaN       7.7
# 2      Michael Craig, John Meillon, Eva Griffith, Gra...       5.7
# 3      Mickey Rourke, Steve Guttenberg, Ellen Barkin,...       7.0
# 7      Don Johnson, Penelope Ann Miller, William Fors...       6.0
# 9      Christopher Walken, Sean Penn, Chris Penn, Mar...       7.5
# ...                                                  ...       ...
# 41377  Cam Gigandet, Jaina Lee Ortiz, Lisa Vidal, Car...       3.7
# 41382  J. Robert Oppenheimer, Kai Bird, Ellen Bradbur...       6.6
# 41384  Jennifer Taylor, Justin C. Schilling, Julia Te...       4.8
# 41385  Maggie Q, Ito Aghayere, Philip Burke, James Ca...       3.5
# 41391  Zoé De Grand Maison, Mather Zickel, Lisa LoCic...       5.0
#
#        critics_vote  public_vote  total_votes  \
# 0              8.00          7.0           22
# 2              6.00          5.0           10
# 3              8.00          6.0           18
# 7              6.00          6.0           27
# 9              7.64          7.0           90
# ...             ...          ...          ...
# 41377          4.00          3.0            7
# 41382          5.00          8.0            8
# 41384           NaN          5.0            4
# 41385          3.00          4.0            5
# 41391          5.50          5.0            8
#
#                                              description  \
# 0      With two protruding front teeth, a slightly sl...
# 2      In the Australia of the pioneers, a boy and a ...
# 3      Five boys from Baltimore have a habit of meeti...
# 7      In the throes of a double murder, Jerry Beck, ...
# 9      Young Brad (Penn) lives with his grandmother a...
# ...                                                  ...
# 41377  Annabel, leader of a secret organization engag...
# 41382  The arrogance, genius and determination of a m...
# 41384  An ambitious real estate agent and his daughte...
# 41385  Tes is a veteran of the war in Iraq invited to...
# 41391  The young abigale Archer is located alone in M...
#
#                                                    notes  humor  rhythm  \
# 0      These are many small independent stories, whic...      3       3
# 2      "Ecological" story with a happy ending, not wi...      1       2
# 3      A cast of will be famous for Levinson's direct...      2       2
# 7      When it comes to talking about mysterious plot...      0       2
# 9      Powerful and brutal thriller, second work by J...      1       3
# ...                                                  ...    ...     ...
# 41377                                                NaN      1       1
# 41382                                                NaN      0       0
# 41384                                                NaN      0       0
# 41385                                                NaN      0       0
# 41391                                                NaN      0       0
#
#        effort  tension  erotism
# 0           0        0        0
# 2           1        0        0
# 3           0        1        2
# 7           0        2        1
# 9           2        4        2
# ...       ...      ...      ...
# 41377       1        1        0
# 41382       0        0        0
# 41384       0        0        0
# 41385       0        0        0
# 41391       0        0        0
#
# [16490 rows x 19 columns]

# %% [markdown]
# # Updating Rows and Columns

# %% [markdown]
# **df.drop:**
# The .drop() method in pandas is used to remove rows or columns from a DataFrame. Its primary purpose is to drop specified labels from rows or columns.
#
# **Parameters:**
#
# **labels:** The row or column labels to drop.
#
# **axis:** Specifies whether the labels refer to rows (axis=0) or columns (axis=1). By default, it's 0 (rows).
#
# **index or columns:** An alternative way to specify the labels to drop, instead of using the labels parameter. It is equivalent to specifying axis=0 (for index) or axis=1 (for columns).
#
# **inplace:** If True, the operation is done in place, meaning it modifies the DataFrame directly and returns None. If False or not specified, it returns a new DataFrame with the specified labels dropped.

# %%
df.drop(labels='title',axis=1)
# Out:
#        filmtv_id  year      genre  duration                country  \
# 0              2  1982  Animation        76          United States
# 1              3  1991      Drama        98                  Italy
# 2             17  1976   Romantic        91          United States
# 3             18  1982     Comedy        95          United States
# 4             20  1942     Comedy        85                  Italy
# ...          ...   ...        ...       ...                    ...
# 41394     232817  2021   Thriller        87  Canada, United States
# 41395     232893  2023     Comedy        90                  Italy
# 41396     232915  2023     Horror       100                 Sweden
# 41397     232919  2023   Thriller        92            South Korea
# 41398     232920  2023   Thriller        92                 Mexico
#
#                                   directors  \
# 0      David Detiege, Art Davis, Bill Perez
# 1                             Luigi Perelli
# 2                               Don Chaffey
# 3                            Barry Levinson
# 4                            Esodo Pratelli
# ...                                     ...
# 41394                            Robin Hays
# 41395                    Francesco Apolloni
# 41396                         Patrik Eklund
# 41397                        Chung-Hyun Lee
# 41398                          J.M Cravioto
#
#                                                   actors  avg_vote  \
# 0                                                    NaN       7.7
# 1      Kim Rossi Stuart, Simona Cavallari, Ennio Fant...       6.5
# 2      Michael Craig, John Meillon, Eva Griffith, Gra...       5.7
# 3      Mickey Rourke, Steve Guttenberg, Ellen Barkin,...       7.0
# 4      Eduardo De Filippo, Peppino De Filippo, Clelia...       5.9
# ...                                                  ...       ...
# 41394  Julie Benz, Roan Curtis, Georgia Bradner, Eli ...       4.0
# 41395  Laura Chiatti, Chiara Francini, Antonia Liskov...       2.7
# 41396  Katia Winter, Eva Melander, Lola Zackow, Adam ...       6.0
# 41397             Jeon Jong-seo, Park Yu-rim, Ji-hun Kim       5.8
# 41398  Maribel Verdú, Stephanie Cayo, Manolo Cardona,...       6.0
#
#        critics_vote  public_vote  total_votes  \
# 0              8.00          7.0           22
# 1              6.00          7.0            4
# 2              6.00          5.0           10
# 3              8.00          6.0           18
# 4              5.33          7.0           15
# ...             ...          ...          ...
# 41394           NaN          4.0            3
# 41395           NaN          3.0            3
# 41396           NaN          6.0            6
# 41397           NaN          6.0            5
# 41398           NaN          6.0            3
#
#                                              description  \
# 0      With two protruding front teeth, a slightly sl...
# 1      Samantha, not yet eighteen, leaves the comfort...
# 2      In the Australia of the pioneers, a boy and a ...
# 3      Five boys from Baltimore have a habit of meeti...
# 4      With a stratagem, the penniless and somewhat p...
# ...                                                  ...
# 41394  Celeste is an attractive waitress in the forti...
# 41395  When Eleonora is downloaded to the altar, her ...
# 41396  A team building conference organized for a gro...
# 41397  Once Ok-Ju worked as a bodyguard and was one o...
# 41398  A great passionate of crime stories is trapped...
#
#                                                    notes  humor  rhythm  \
# 0      These are many small independent stories, whic...      3       3
# 1      Luigi Perelli, the director of the "Piovra", o...      0       2
# 2      "Ecological" story with a happy ending, not wi...      1       2
# 3      A cast of will be famous for Levinson's direct...      2       2
# 4      Taken from the play by Armando Curcio that the...      3       1
# ...                                                  ...    ...     ...
# 41394                    Freely taken from a true story.      0       0
# 41395                   Bachelorette fare sequel (2021).      0       0
# 41396                                                NaN      0       0
# 41397                                                NaN      0       0
# 41398                                                NaN      0       0
#
#        effort  tension  erotism
# 0           0        0        0
# 1           0        2        0
# 2           1        0        0
# 3           0        1        2
# 4           1        0        0
# ...       ...      ...      ...
# 41394       0        0        0
# 41395       0        0        0
# 41396       0        0        0
# 41397       0        0        0
# 41398       0        0        0
#
# [41399 rows x 18 columns]

# %%
df
# Out:
#        filmtv_id                                        title  year  \
# 0              2  Bugs Bunny's Third Movie: 1001 Rabbit Tales  1982
# 1              3                    18 anni tra una settimana  1991
# 2             17                             Ride a Wild Pony  1976
# 3             18                                        Diner  1982
# 4             20              A che servono questi quattrini?  1942
# ...          ...                                          ...   ...
# 41394     232817                           Gold Digger Killer  2021
# 41395     232893                          Addio al nubilato 2  2023
# 41396     232915                                  Konferensen  2023
# 41397     232919                                    Ballelina  2023
# 41398     232920                    Invitación a un Asesinato  2023
#
#            genre  duration                country  \
# 0      Animation        76          United States
# 1          Drama        98                  Italy
# 2       Romantic        91          United States
# 3         Comedy        95          United States
# 4         Comedy        85                  Italy
# ...          ...       ...                    ...
# 41394   Thriller        87  Canada, United States
# 41395     Comedy        90                  Italy
# 41396     Horror       100                 Sweden
# 41397   Thriller        92            South Korea
# 41398   Thriller        92                 Mexico
#
#                                   directors  \
# 0      David Detiege, Art Davis, Bill Perez
# 1                             Luigi Perelli
# 2                               Don Chaffey
# 3                            Barry Levinson
# 4                            Esodo Pratelli
# ...                                     ...
# 41394                            Robin Hays
# 41395                    Francesco Apolloni
# 41396                         Patrik Eklund
# 41397                        Chung-Hyun Lee
# 41398                          J.M Cravioto
#
#                                                   actors  avg_vote  \
# 0                                                    NaN       7.7
# 1      Kim Rossi Stuart, Simona Cavallari, Ennio Fant...       6.5
# 2      Michael Craig, John Meillon, Eva Griffith, Gra...       5.7
# 3      Mickey Rourke, Steve Guttenberg, Ellen Barkin,...       7.0
# 4      Eduardo De Filippo, Peppino De Filippo, Clelia...       5.9
# ...                                                  ...       ...
# 41394  Julie Benz, Roan Curtis, Georgia Bradner, Eli ...       4.0
# 41395  Laura Chiatti, Chiara Francini, Antonia Liskov...       2.7
# 41396  Katia Winter, Eva Melander, Lola Zackow, Adam ...       6.0
# 41397             Jeon Jong-seo, Park Yu-rim, Ji-hun Kim       5.8
# 41398  Maribel Verdú, Stephanie Cayo, Manolo Cardona,...       6.0
#
#        critics_vote  public_vote  total_votes  \
# 0              8.00          7.0           22
# 1              6.00          7.0            4
# 2              6.00          5.0           10
# 3              8.00          6.0           18
# 4              5.33          7.0           15
# ...             ...          ...          ...
# 41394           NaN          4.0            3
# 41395           NaN          3.0            3
# 41396           NaN          6.0            6
# 41397           NaN          6.0            5
# 41398           NaN          6.0            3
#
#                                              description  \
# 0      With two protruding front teeth, a slightly sl...
# 1      Samantha, not yet eighteen, leaves the comfort...
# 2      In the Australia of the pioneers, a boy and a ...
# 3      Five boys from Baltimore have a habit of meeti...
# 4      With a stratagem, the penniless and somewhat p...
# ...                                                  ...
# 41394  Celeste is an attractive waitress in the forti...
# 41395  When Eleonora is downloaded to the altar, her ...
# 41396  A team building conference organized for a gro...
# 41397  Once Ok-Ju worked as a bodyguard and was one o...
# 41398  A great passionate of crime stories is trapped...
#
#                                                    notes  humor  rhythm  \
# 0      These are many small independent stories, whic...      3       3
# 1      Luigi Perelli, the director of the "Piovra", o...      0       2
# 2      "Ecological" story with a happy ending, not wi...      1       2
# 3      A cast of will be famous for Levinson's direct...      2       2
# 4      Taken from the play by Armando Curcio that the...      3       1
# ...                                                  ...    ...     ...
# 41394                    Freely taken from a true story.      0       0
# 41395                   Bachelorette fare sequel (2021).      0       0
# 41396                                                NaN      0       0
# 41397                                                NaN      0       0
# 41398                                                NaN      0       0
#
#        effort  tension  erotism
# 0           0        0        0
# 1           0        2        0
# 2           1        0        0
# 3           0        1        2
# 4           1        0        0
# ...       ...      ...      ...
# 41394       0        0        0
# 41395       0        0        0
# 41396       0        0        0
# 41397       0        0        0
# 41398       0        0        0
#
# [41399 rows x 19 columns]

# %% [markdown]
# **Direct Assignment:**
# Directly assign a value to a specific column or even a cell in a DataFrame.

# %%
df.at[0, 'year'] = 1983  # Changes the year of the first movie to 1983
df.head(5)
# Out:
#    filmtv_id                                        title  year      genre  \
# 0          2  Bugs Bunny's Third Movie: 1001 Rabbit Tales  1983  Animation
# 1          3                    18 anni tra una settimana  1991      Drama
# 2         17                             Ride a Wild Pony  1976   Romantic
# 3         18                                        Diner  1982     Comedy
# 4         20              A che servono questi quattrini?  1942     Comedy
#
#    duration        country                             directors  \
# 0        76  United States  David Detiege, Art Davis, Bill Perez
# 1        98          Italy                         Luigi Perelli
# 2        91  United States                           Don Chaffey
# 3        95  United States                        Barry Levinson
# 4        85          Italy                        Esodo Pratelli
#
#                                               actors  avg_vote  critics_vote  \
# 0                                                NaN       7.7          8.00
# 1  Kim Rossi Stuart, Simona Cavallari, Ennio Fant...       6.5          6.00
# 2  Michael Craig, John Meillon, Eva Griffith, Gra...       5.7          6.00
# 3  Mickey Rourke, Steve Guttenberg, Ellen Barkin,...       7.0          8.00
# 4  Eduardo De Filippo, Peppino De Filippo, Clelia...       5.9          5.33
#
#    public_vote  total_votes  \
# 0          7.0           22
# 1          7.0            4
# 2          5.0           10
# 3          6.0           18
# 4          7.0           15
#
#                                          description  \
# 0  With two protruding front teeth, a slightly sl...
# 1  Samantha, not yet eighteen, leaves the comfort...
# 2  In the Australia of the pioneers, a boy and a ...
# 3  Five boys from Baltimore have a habit of meeti...
# 4  With a stratagem, the penniless and somewhat p...
#
#                                                notes  humor  rhythm  effort  \
# 0  These are many small independent stories, whic...      3       3       0
# 1  Luigi Perelli, the director of the "Piovra", o...      0       2       0
# 2  "Ecological" story with a happy ending, not wi...      1       2       1
# 3  A cast of will be famous for Levinson's direct...      2       2       0
# 4  Taken from the play by Armando Curcio that the...      3       1       1
#
#    tension  erotism
# 0        0        0
# 1        2        0
# 2        0        0
# 3        1        2
# 4        0        0

# %%
df['new_column'] = 'default value'  # Adds a new column with all entries set to 'default value'
df
# Out:
#        filmtv_id                                        title  year  \
# 0              2  Bugs Bunny's Third Movie: 1001 Rabbit Tales  1983
# 1              3                    18 anni tra una settimana  1991
# 2             17                             Ride a Wild Pony  1976
# 3             18                                        Diner  1982
# 4             20              A che servono questi quattrini?  1942
# ...          ...                                          ...   ...
# 41394     232817                           Gold Digger Killer  2021
# 41395     232893                          Addio al nubilato 2  2023
# 41396     232915                                  Konferensen  2023
# 41397     232919                                    Ballelina  2023
# 41398     232920                    Invitación a un Asesinato  2023
#
#            genre  duration                country  \
# 0      Animation        76          United States
# 1          Drama        98                  Italy
# 2       Romantic        91          United States
# 3         Comedy        95          United States
# 4         Comedy        85                  Italy
# ...          ...       ...                    ...
# 41394   Thriller        87  Canada, United States
# 41395     Comedy        90                  Italy
# 41396     Horror       100                 Sweden
# 41397   Thriller        92            South Korea
# 41398   Thriller        92                 Mexico
#
#                                   directors  \
# 0      David Detiege, Art Davis, Bill Perez
# 1                             Luigi Perelli
# 2                               Don Chaffey
# 3                            Barry Levinson
# 4                            Esodo Pratelli
# ...                                     ...
# 41394                            Robin Hays
# 41395                    Francesco Apolloni
# 41396                         Patrik Eklund
# 41397                        Chung-Hyun Lee
# 41398                          J.M Cravioto
#
#                                                   actors  avg_vote  \
# 0                                                    NaN       7.7
# 1      Kim Rossi Stuart, Simona Cavallari, Ennio Fant...       6.5
# 2      Michael Craig, John Meillon, Eva Griffith, Gra...       5.7
# 3      Mickey Rourke, Steve Guttenberg, Ellen Barkin,...       7.0
# 4      Eduardo De Filippo, Peppino De Filippo, Clelia...       5.9
# ...                                                  ...       ...
# 41394  Julie Benz, Roan Curtis, Georgia Bradner, Eli ...       4.0
# 41395  Laura Chiatti, Chiara Francini, Antonia Liskov...       2.7
# 41396  Katia Winter, Eva Melander, Lola Zackow, Adam ...       6.0
# 41397             Jeon Jong-seo, Park Yu-rim, Ji-hun Kim       5.8
# 41398  Maribel Verdú, Stephanie Cayo, Manolo Cardona,...       6.0
#
#        critics_vote  public_vote  total_votes  \
# 0              8.00          7.0           22
# 1              6.00          7.0            4
# 2              6.00          5.0           10
# 3              8.00          6.0           18
# 4              5.33          7.0           15
# ...             ...          ...          ...
# 41394           NaN          4.0            3
# 41395           NaN          3.0            3
# 41396           NaN          6.0            6
# 41397           NaN          6.0            5
# 41398           NaN          6.0            3
#
#                                              description  \
# 0      With two protruding front teeth, a slightly sl...
# 1      Samantha, not yet eighteen, leaves the comfort...
# 2      In the Australia of the pioneers, a boy and a ...
# 3      Five boys from Baltimore have a habit of meeti...
# 4      With a stratagem, the penniless and somewhat p...
# ...                                                  ...
# 41394  Celeste is an attractive waitress in the forti...
# 41395  When Eleonora is downloaded to the altar, her ...
# 41396  A team building conference organized for a gro...
# 41397  Once Ok-Ju worked as a bodyguard and was one o...
# 41398  A great passionate of crime stories is trapped...
#
#                                                    notes  humor  rhythm  \
# 0      These are many small independent stories, whic...      3       3
# 1      Luigi Perelli, the director of the "Piovra", o...      0       2
# 2      "Ecological" story with a happy ending, not wi...      1       2
# 3      A cast of will be famous for Levinson's direct...      2       2
# 4      Taken from the play by Armando Curcio that the...      3       1
# ...                                                  ...    ...     ...
# 41394                    Freely taken from a true story.      0       0
# 41395                   Bachelorette fare sequel (2021).      0       0
# 41396                                                NaN      0       0
# 41397                                                NaN      0       0
# 41398                                                NaN      0       0
#
#        effort  tension  erotism     new_column
# 0           0        0        0  default value
# 1           0        2        0  default value
# 2           1        0        0  default value
# 3           0        1        2  default value
# 4           1        0        0  default value
# ...       ...      ...      ...            ...
# 41394       0        0        0  default value
# 41395       0        0        0  default value
# 41396       0        0        0  default value
# 41397       0        0        0  default value
# 41398       0        0        0  default value
#
# [41399 rows x 20 columns]

# %%
df.drop(axis=1,labels='new_column',inplace=True)

# %%
df.head(5)
# Out:
#    filmtv_id                                        title  year      genre  \
# 0          2  Bugs Bunny's Third Movie: 1001 Rabbit Tales  1983  Animation
# 1          3                    18 anni tra una settimana  1991      Drama
# 2         17                             Ride a Wild Pony  1976   Romantic
# 3         18                                        Diner  1982     Comedy
# 4         20              A che servono questi quattrini?  1942     Comedy
#
#    duration        country                             directors  \
# 0        76  United States  David Detiege, Art Davis, Bill Perez
# 1        98          Italy                         Luigi Perelli
# 2        91  United States                           Don Chaffey
# 3        95  United States                        Barry Levinson
# 4        85          Italy                        Esodo Pratelli
#
#                                               actors  avg_vote  critics_vote  \
# 0                                                NaN       7.7          8.00
# 1  Kim Rossi Stuart, Simona Cavallari, Ennio Fant...       6.5          6.00
# 2  Michael Craig, John Meillon, Eva Griffith, Gra...       5.7          6.00
# 3  Mickey Rourke, Steve Guttenberg, Ellen Barkin,...       7.0          8.00
# 4  Eduardo De Filippo, Peppino De Filippo, Clelia...       5.9          5.33
#
#    public_vote  total_votes  \
# 0          7.0           22
# 1          7.0            4
# 2          5.0           10
# 3          6.0           18
# 4          7.0           15
#
#                                          description  \
# 0  With two protruding front teeth, a slightly sl...
# 1  Samantha, not yet eighteen, leaves the comfort...
# 2  In the Australia of the pioneers, a boy and a ...
# 3  Five boys from Baltimore have a habit of meeti...
# 4  With a stratagem, the penniless and somewhat p...
#
#                                                notes  humor  rhythm  effort  \
# 0  These are many small independent stories, whic...      3       3       0
# 1  Luigi Perelli, the director of the "Piovra", o...      0       2       0
# 2  "Ecological" story with a happy ending, not wi...      1       2       1
# 3  A cast of will be famous for Levinson's direct...      2       2       0
# 4  Taken from the play by Armando Curcio that the...      3       1       1
#
#    tension  erotism
# 0        0        0
# 1        2        0
# 2        0        0
# 3        1        2
# 4        0        0

# %% [markdown]
# **Using loc for Conditional Updates:**
# loc can be used to update rows and columns based on a condition.

# %%
df.loc[df['year'] < 2000, 'classic'] = True  # Marks movies before 2000 as classic
df
# Out:
#        filmtv_id                                        title  year  \
# 0              2  Bugs Bunny's Third Movie: 1001 Rabbit Tales  1983
# 1              3                    18 anni tra una settimana  1991
# 2             17                             Ride a Wild Pony  1976
# 3             18                                        Diner  1982
# 4             20              A che servono questi quattrini?  1942
# ...          ...                                          ...   ...
# 41394     232817                           Gold Digger Killer  2021
# 41395     232893                          Addio al nubilato 2  2023
# 41396     232915                                  Konferensen  2023
# 41397     232919                                    Ballelina  2023
# 41398     232920                    Invitación a un Asesinato  2023
#
#            genre  duration                country  \
# 0      Animation        76          United States
# 1          Drama        98                  Italy
# 2       Romantic        91          United States
# 3         Comedy        95          United States
# 4         Comedy        85                  Italy
# ...          ...       ...                    ...
# 41394   Thriller        87  Canada, United States
# 41395     Comedy        90                  Italy
# 41396     Horror       100                 Sweden
# 41397   Thriller        92            South Korea
# 41398   Thriller        92                 Mexico
#
#                                   directors  \
# 0      David Detiege, Art Davis, Bill Perez
# 1                             Luigi Perelli
# 2                               Don Chaffey
# 3                            Barry Levinson
# 4                            Esodo Pratelli
# ...                                     ...
# 41394                            Robin Hays
# 41395                    Francesco Apolloni
# 41396                         Patrik Eklund
# 41397                        Chung-Hyun Lee
# 41398                          J.M Cravioto
#
#                                                   actors  avg_vote  \
# 0                                                    NaN       7.7
# 1      Kim Rossi Stuart, Simona Cavallari, Ennio Fant...       6.5
# 2      Michael Craig, John Meillon, Eva Griffith, Gra...       5.7
# 3      Mickey Rourke, Steve Guttenberg, Ellen Barkin,...       7.0
# 4      Eduardo De Filippo, Peppino De Filippo, Clelia...       5.9
# ...                                                  ...       ...
# 41394  Julie Benz, Roan Curtis, Georgia Bradner, Eli ...       4.0
# 41395  Laura Chiatti, Chiara Francini, Antonia Liskov...       2.7
# 41396  Katia Winter, Eva Melander, Lola Zackow, Adam ...       6.0
# 41397             Jeon Jong-seo, Park Yu-rim, Ji-hun Kim       5.8
# 41398  Maribel Verdú, Stephanie Cayo, Manolo Cardona,...       6.0
#
#        critics_vote  public_vote  total_votes  \
# 0              8.00          7.0           22
# 1              6.00          7.0            4
# 2              6.00          5.0           10
# 3              8.00          6.0           18
# 4              5.33          7.0           15
# ...             ...          ...          ...
# 41394           NaN          4.0            3
# 41395           NaN          3.0            3
# 41396           NaN          6.0            6
# 41397           NaN          6.0            5
# 41398           NaN          6.0            3
#
#                                              description  \
# 0      With two protruding front teeth, a slightly sl...
# 1      Samantha, not yet eighteen, leaves the comfort...
# 2      In the Australia of the pioneers, a boy and a ...
# 3      Five boys from Baltimore have a habit of meeti...
# 4      With a stratagem, the penniless and somewhat p...
# ...                                                  ...
# 41394  Celeste is an attractive waitress in the forti...
# 41395  When Eleonora is downloaded to the altar, her ...
# 41396  A team building conference organized for a gro...
# 41397  Once Ok-Ju worked as a bodyguard and was one o...
# 41398  A great passionate of crime stories is trapped...
#
#                                                    notes  humor  rhythm  \
# 0      These are many small independent stories, whic...      3       3
# 1      Luigi Perelli, the director of the "Piovra", o...      0       2
# 2      "Ecological" story with a happy ending, not wi...      1       2
# 3      A cast of will be famous for Levinson's direct...      2       2
# 4      Taken from the play by Armando Curcio that the...      3       1
# ...                                                  ...    ...     ...
# 41394                    Freely taken from a true story.      0       0
# 41395                   Bachelorette fare sequel (2021).      0       0
# 41396                                                NaN      0       0
# 41397                                                NaN      0       0
# 41398                                                NaN      0       0
#
#        effort  tension  erotism classic
# 0           0        0        0    True
# 1           0        2        0    True
# 2           1        0        0    True
# 3           0        1        2    True
# 4           1        0        0    True
# ...       ...      ...      ...     ...
# 41394       0        0        0     NaN
# 41395       0        0        0     NaN
# 41396       0        0        0     NaN
# 41397       0        0        0     NaN
# 41398       0        0        0     NaN
#
# [41399 rows x 20 columns]

# %%
df.loc[df['avg_vote'] > 6, ['top_rated', 'must_watch']] = [True, True] # Modifying multiple columns using loc

# %%
df
# Out:
#        filmtv_id                                        title  year  \
# 0              2  Bugs Bunny's Third Movie: 1001 Rabbit Tales  1983
# 1              3                    18 anni tra una settimana  1991
# 2             17                             Ride a Wild Pony  1976
# 3             18                                        Diner  1982
# 4             20              A che servono questi quattrini?  1942
# ...          ...                                          ...   ...
# 41394     232817                           Gold Digger Killer  2021
# 41395     232893                          Addio al nubilato 2  2023
# 41396     232915                                  Konferensen  2023
# 41397     232919                                    Ballelina  2023
# 41398     232920                    Invitación a un Asesinato  2023
#
#            genre  duration                country  \
# 0      Animation        76          United States
# 1          Drama        98                  Italy
# 2       Romantic        91          United States
# 3         Comedy        95          United States
# 4         Comedy        85                  Italy
# ...          ...       ...                    ...
# 41394   Thriller        87  Canada, United States
# 41395     Comedy        90                  Italy
# 41396     Horror       100                 Sweden
# 41397   Thriller        92            South Korea
# 41398   Thriller        92                 Mexico
#
#                                   directors  \
# 0      David Detiege, Art Davis, Bill Perez
# 1                             Luigi Perelli
# 2                               Don Chaffey
# 3                            Barry Levinson
# 4                            Esodo Pratelli
# ...                                     ...
# 41394                            Robin Hays
# 41395                    Francesco Apolloni
# 41396                         Patrik Eklund
# 41397                        Chung-Hyun Lee
# 41398                          J.M Cravioto
#
#                                                   actors  avg_vote  \
# 0                                                    NaN       7.7
# 1      Kim Rossi Stuart, Simona Cavallari, Ennio Fant...       6.5
# 2      Michael Craig, John Meillon, Eva Griffith, Gra...       5.7
# 3      Mickey Rourke, Steve Guttenberg, Ellen Barkin,...       7.0
# 4      Eduardo De Filippo, Peppino De Filippo, Clelia...       5.9
# ...                                                  ...       ...
# 41394  Julie Benz, Roan Curtis, Georgia Bradner, Eli ...       4.0
# 41395  Laura Chiatti, Chiara Francini, Antonia Liskov...       2.7
# 41396  Katia Winter, Eva Melander, Lola Zackow, Adam ...       6.0
# 41397             Jeon Jong-seo, Park Yu-rim, Ji-hun Kim       5.8
# 41398  Maribel Verdú, Stephanie Cayo, Manolo Cardona,...       6.0
#
#        critics_vote  ...                                        description  \
# 0              8.00  ...  With two protruding front teeth, a slightly sl...
# 1              6.00  ...  Samantha, not yet eighteen, leaves the comfort...
# 2              6.00  ...  In the Australia of the pioneers, a boy and a ...
# 3              8.00  ...  Five boys from Baltimore have a habit of meeti...
# 4              5.33  ...  With a stratagem, the penniless and somewhat p...
# ...             ...  ...                                                ...
# 41394           NaN  ...  Celeste is an attractive waitress in the forti...
# 41395           NaN  ...  When Eleonora is downloaded to the altar, her ...
# 41396           NaN  ...  A team building conference organized for a gro...
# 41397           NaN  ...  Once Ok-Ju worked as a bodyguard and was one o...
# 41398           NaN  ...  A great passionate of crime stories is trapped...
#
#                                                    notes humor rhythm  effort  \
# 0      These are many small independent stories, whic...     3      3       0
# 1      Luigi Perelli, the director of the "Piovra", o...     0      2       0
# 2      "Ecological" story with a happy ending, not wi...     1      2       1
# 3      A cast of will be famous for Levinson's direct...     2      2       0
# 4      Taken from the play by Armando Curcio that the...     3      1       1
# ...                                                  ...   ...    ...     ...
# 41394                    Freely taken from a true story.     0      0       0
# 41395                   Bachelorette fare sequel (2021).     0      0       0
# 41396                                                NaN     0      0       0
# 41397                                                NaN     0      0       0
# 41398                                                NaN     0      0       0
#
#        tension  erotism  classic  top_rated must_watch
# 0            0        0     True       True       True
# 1            2        0     True       True       True
# 2            0        0     True        NaN        NaN
# 3            1        2     True       True       True
# 4            0        0     True        NaN        NaN
# ...        ...      ...      ...        ...        ...
# 41394        0        0      NaN        NaN        NaN
# 41395        0        0      NaN        NaN        NaN
# 41396        0        0      NaN        NaN        NaN
# 41397        0        0      NaN        NaN        NaN
# 41398        0        0      NaN        NaN        NaN
#
# [41399 rows x 22 columns]

# %% [markdown]
# **Using apply Function:**
# The apply function allows you to apply a function along an axis of the DataFrame.

# %%
df['length_category'] = df['duration'].apply(lambda x: 'Long' if x > 120 else 'Short')
df
# Out:
#        filmtv_id                                        title  year  \
# 0              2  Bugs Bunny's Third Movie: 1001 Rabbit Tales  1983
# 1              3                    18 anni tra una settimana  1991
# 2             17                             Ride a Wild Pony  1976
# 3             18                                        Diner  1982
# 4             20              A che servono questi quattrini?  1942
# ...          ...                                          ...   ...
# 41394     232817                           Gold Digger Killer  2021
# 41395     232893                          Addio al nubilato 2  2023
# 41396     232915                                  Konferensen  2023
# 41397     232919                                    Ballelina  2023
# 41398     232920                    Invitación a un Asesinato  2023
#
#            genre  duration                country  \
# 0      Animation        76          United States
# 1          Drama        98                  Italy
# 2       Romantic        91          United States
# 3         Comedy        95          United States
# 4         Comedy        85                  Italy
# ...          ...       ...                    ...
# 41394   Thriller        87  Canada, United States
# 41395     Comedy        90                  Italy
# 41396     Horror       100                 Sweden
# 41397   Thriller        92            South Korea
# 41398   Thriller        92                 Mexico
#
#                                   directors  \
# 0      David Detiege, Art Davis, Bill Perez
# 1                             Luigi Perelli
# 2                               Don Chaffey
# 3                            Barry Levinson
# 4                            Esodo Pratelli
# ...                                     ...
# 41394                            Robin Hays
# 41395                    Francesco Apolloni
# 41396                         Patrik Eklund
# 41397                        Chung-Hyun Lee
# 41398                          J.M Cravioto
#
#                                                   actors  avg_vote  \
# 0                                                    NaN       7.7
# 1      Kim Rossi Stuart, Simona Cavallari, Ennio Fant...       6.5
# 2      Michael Craig, John Meillon, Eva Griffith, Gra...       5.7
# 3      Mickey Rourke, Steve Guttenberg, Ellen Barkin,...       7.0
# 4      Eduardo De Filippo, Peppino De Filippo, Clelia...       5.9
# ...                                                  ...       ...
# 41394  Julie Benz, Roan Curtis, Georgia Bradner, Eli ...       4.0
# 41395  Laura Chiatti, Chiara Francini, Antonia Liskov...       2.7
# 41396  Katia Winter, Eva Melander, Lola Zackow, Adam ...       6.0
# 41397             Jeon Jong-seo, Park Yu-rim, Ji-hun Kim       5.8
# 41398  Maribel Verdú, Stephanie Cayo, Manolo Cardona,...       6.0
#
#        critics_vote  ...                                              notes  \
# 0              8.00  ...  These are many small independent stories, whic...
# 1              6.00  ...  Luigi Perelli, the director of the "Piovra", o...
# 2              6.00  ...  "Ecological" story with a happy ending, not wi...
# 3              8.00  ...  A cast of will be famous for Levinson's direct...
# 4              5.33  ...  Taken from the play by Armando Curcio that the...
# ...             ...  ...                                                ...
# 41394           NaN  ...                    Freely taken from a true story.
# 41395           NaN  ...                   Bachelorette fare sequel (2021).
# 41396           NaN  ...                                                NaN
# 41397           NaN  ...                                                NaN
# 41398           NaN  ...                                                NaN
#
#        humor rhythm effort  tension  erotism  classic  top_rated  must_watch  \
# 0          3      3      0        0        0     True       True        True
# 1          0      2      0        2        0     True       True        True
# 2          1      2      1        0        0     True        NaN         NaN
# 3          2      2      0        1        2     True       True        True
# 4          3      1      1        0        0     True        NaN         NaN
# ...      ...    ...    ...      ...      ...      ...        ...         ...
# 41394      0      0      0        0        0      NaN        NaN         NaN
# 41395      0      0      0        0        0      NaN        NaN         NaN
# 41396      0      0      0        0        0      NaN        NaN         NaN
# 41397      0      0      0        0        0      NaN        NaN         NaN
# 41398      0      0      0        0        0      NaN        NaN         NaN
#
#       length_category
# 0               Short
# 1               Short
# 2               Short
# 3               Short
# 4               Short
# ...               ...
# 41394           Short
# 41395           Short
# 41396           Short
# 41397           Short
# 41398           Short
#
# [41399 rows x 23 columns]

# %%
# Create a DataFrame with multiple Series
data = {
    'A': [1, 2, 3],
    'B': [4, 5, 6],
    'C': [7, 8, 9]
}
num_data = pd.DataFrame(data)

# %%
num_data
# Out:
#    A  B  C
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %%
# Define a function to sum two Series
def sum_series(x, y):
    return x + y

# Apply the function on multiple Series using apply()
result = num_data.apply(lambda row: sum_series(row['A'], row['B']), axis=1)

# Print the result
print(result)
# Out:
# 0    5
# 1    7
# 2    9
# dtype: int64

# %% [markdown]
# **Updating Using map or replace:**
# You can update a column based on a mapping dictionary or replace values.

# %%
df['genre'].map({'Drama': 'Drama Film', 'Comedy': 'Comedy Film'}) # Mapping existing values to new ones
# Out:
# 0                NaN
# 1         Drama Film
# 2                NaN
# 3        Comedy Film
# 4        Comedy Film
#             ...
# 41394            NaN
# 41395    Comedy Film
# 41396            NaN
# 41397            NaN
# 41398            NaN
# Name: genre, Length: 41399, dtype: object

# %%
df['country'].replace('USA', 'United States', inplace=True) # Replacing specific values
df
# Out:
#        filmtv_id                                        title  year  \
# 0              2  Bugs Bunny's Third Movie: 1001 Rabbit Tales  1982
# 1              3                    18 anni tra una settimana  1991
# 2             17                             Ride a Wild Pony  1976
# 3             18                                        Diner  1982
# 4             20              A che servono questi quattrini?  1942
# ...          ...                                          ...   ...
# 41394     232817                           Gold Digger Killer  2021
# 41395     232893                          Addio al nubilato 2  2023
# 41396     232915                                  Konferensen  2023
# 41397     232919                                    Ballelina  2023
# 41398     232920                    Invitación a un Asesinato  2023
#
#            genre  duration                country  \
# 0      Animation        76          United States
# 1          Drama        98                  Italy
# 2       Romantic        91          United States
# 3         Comedy        95          United States
# 4         Comedy        85                  Italy
# ...          ...       ...                    ...
# 41394   Thriller        87  Canada, United States
# 41395     Comedy        90                  Italy
# 41396     Horror       100                 Sweden
# 41397   Thriller        92            South Korea
# 41398   Thriller        92                 Mexico
#
#                                   directors  \
# 0      David Detiege, Art Davis, Bill Perez
# 1                             Luigi Perelli
# 2                               Don Chaffey
# 3                            Barry Levinson
# 4                            Esodo Pratelli
# ...                                     ...
# 41394                            Robin Hays
# 41395                    Francesco Apolloni
# 41396                         Patrik Eklund
# 41397                        Chung-Hyun Lee
# 41398                          J.M Cravioto
#
#                                                   actors  avg_vote  \
# 0                                                    NaN       7.7
# 1      Kim Rossi Stuart, Simona Cavallari, Ennio Fant...       6.5
# 2      Michael Craig, John Meillon, Eva Griffith, Gra...       5.7
# 3      Mickey Rourke, Steve Guttenberg, Ellen Barkin,...       7.0
# 4      Eduardo De Filippo, Peppino De Filippo, Clelia...       5.9
# ...                                                  ...       ...
# 41394  Julie Benz, Roan Curtis, Georgia Bradner, Eli ...       4.0
# 41395  Laura Chiatti, Chiara Francini, Antonia Liskov...       2.7
# 41396  Katia Winter, Eva Melander, Lola Zackow, Adam ...       6.0
# 41397             Jeon Jong-seo, Park Yu-rim, Ji-hun Kim       5.8
# 41398  Maribel Verdú, Stephanie Cayo, Manolo Cardona,...       6.0
#
#        critics_vote  public_vote  total_votes  \
# 0              8.00          7.0           22
# 1              6.00          7.0            4
# 2              6.00          5.0           10
# 3              8.00          6.0           18
# 4              5.33          7.0           15
# ...             ...          ...          ...
# 41394           NaN          4.0            3
# 41395           NaN          3.0            3
# 41396           NaN          6.0            6
# 41397           NaN          6.0            5
# 41398           NaN          6.0            3
#
#                                              description  \
# 0      With two protruding front teeth, a slightly sl...
# 1      Samantha, not yet eighteen, leaves the comfort...
# 2      In the Australia of the pioneers, a boy and a ...
# 3      Five boys from Baltimore have a habit of meeti...
# 4      With a stratagem, the penniless and somewhat p...
# ...                                                  ...
# 41394  Celeste is an attractive waitress in the forti...
# 41395  When Eleonora is downloaded to the altar, her ...
# 41396  A team building conference organized for a gro...
# 41397  Once Ok-Ju worked as a bodyguard and was one o...
# 41398  A great passionate of crime stories is trapped...
#
#                                                    notes  humor  rhythm  \
# 0      These are many small independent stories, whic...      3       3
# 1      Luigi Perelli, the director of the "Piovra", o...      0       2
# 2      "Ecological" story with a happy ending, not wi...      1       2
# 3      A cast of will be famous for Levinson's direct...      2       2
# 4      Taken from the play by Armando Curcio that the...      3       1
# ...                                                  ...    ...     ...
# 41394                    Freely taken from a true story.      0       0
# 41395                   Bachelorette fare sequel (2021).      0       0
# 41396                                                NaN      0       0
# 41397                                                NaN      0       0
# 41398                                                NaN      0       0
#
#        effort  tension  erotism
# 0           0        0        0
# 1           0        2        0
# 2           1        0        0
# 3           0        1        2
# 4           1        0        0
# ...       ...      ...      ...
# 41394       0        0        0
# 41395       0        0        0
# 41396       0        0        0
# 41397       0        0        0
# 41398       0        0        0
#
# [41399 rows x 19 columns]

# %% [markdown]
# **Adding New Columns Based on Calculations:**
# You can create new columns based on calculations from existing columns.

# %%
df['title_year'] = df['title'] + " (" + df['year'].astype(str) + ")" # Creating a new column by combining existing columns
df
# Out:
#        filmtv_id                                        title  year  \
# 0              2  Bugs Bunny's Third Movie: 1001 Rabbit Tales  1982
# 1              3                    18 anni tra una settimana  1991
# 2             17                             Ride a Wild Pony  1976
# 3             18                                        Diner  1982
# 4             20              A che servono questi quattrini?  1942
# ...          ...                                          ...   ...
# 41394     232817                           Gold Digger Killer  2021
# 41395     232893                          Addio al nubilato 2  2023
# 41396     232915                                  Konferensen  2023
# 41397     232919                                    Ballelina  2023
# 41398     232920                    Invitación a un Asesinato  2023
#
#            genre  duration                country  \
# 0      Animation        76          United States
# 1          Drama        98                  Italy
# 2       Romantic        91          United States
# 3         Comedy        95          United States
# 4         Comedy        85                  Italy
# ...          ...       ...                    ...
# 41394   Thriller        87  Canada, United States
# 41395     Comedy        90                  Italy
# 41396     Horror       100                 Sweden
# 41397   Thriller        92            South Korea
# 41398   Thriller        92                 Mexico
#
#                                   directors  \
# 0      David Detiege, Art Davis, Bill Perez
# 1                             Luigi Perelli
# 2                               Don Chaffey
# 3                            Barry Levinson
# 4                            Esodo Pratelli
# ...                                     ...
# 41394                            Robin Hays
# 41395                    Francesco Apolloni
# 41396                         Patrik Eklund
# 41397                        Chung-Hyun Lee
# 41398                          J.M Cravioto
#
#                                                   actors  avg_vote  \
# 0                                                    NaN       7.7
# 1      Kim Rossi Stuart, Simona Cavallari, Ennio Fant...       6.5
# 2      Michael Craig, John Meillon, Eva Griffith, Gra...       5.7
# 3      Mickey Rourke, Steve Guttenberg, Ellen Barkin,...       7.0
# 4      Eduardo De Filippo, Peppino De Filippo, Clelia...       5.9
# ...                                                  ...       ...
# 41394  Julie Benz, Roan Curtis, Georgia Bradner, Eli ...       4.0
# 41395  Laura Chiatti, Chiara Francini, Antonia Liskov...       2.7
# 41396  Katia Winter, Eva Melander, Lola Zackow, Adam ...       6.0
# 41397             Jeon Jong-seo, Park Yu-rim, Ji-hun Kim       5.8
# 41398  Maribel Verdú, Stephanie Cayo, Manolo Cardona,...       6.0
#
#        critics_vote  public_vote  total_votes  \
# 0              8.00          7.0           22
# 1              6.00          7.0            4
# 2              6.00          5.0           10
# 3              8.00          6.0           18
# 4              5.33          7.0           15
# ...             ...          ...          ...
# 41394           NaN          4.0            3
# 41395           NaN          3.0            3
# 41396           NaN          6.0            6
# 41397           NaN          6.0            5
# 41398           NaN          6.0            3
#
#                                              description  \
# 0      With two protruding front teeth, a slightly sl...
# 1      Samantha, not yet eighteen, leaves the comfort...
# 2      In the Australia of the pioneers, a boy and a ...
# 3      Five boys from Baltimore have a habit of meeti...
# 4      With a stratagem, the penniless and somewhat p...
# ...                                                  ...
# 41394  Celeste is an attractive waitress in the forti...
# 41395  When Eleonora is downloaded to the altar, her ...
# 41396  A team building conference organized for a gro...
# 41397  Once Ok-Ju worked as a bodyguard and was one o...
# 41398  A great passionate of crime stories is trapped...
#
#                                                    notes  humor  rhythm  \
# 0      These are many small independent stories, whic...      3       3
# 1      Luigi Perelli, the director of the "Piovra", o...      0       2
# 2      "Ecological" story with a happy ending, not wi...      1       2
# 3      A cast of will be famous for Levinson's direct...      2       2
# 4      Taken from the play by Armando Curcio that the...      3       1
# ...                                                  ...    ...     ...
# 41394                    Freely taken from a true story.      0       0
# 41395                   Bachelorette fare sequel (2021).      0       0
# 41396                                                NaN      0       0
# 41397                                                NaN      0       0
# 41398                                                NaN      0       0
#
#        effort  tension  erotism  \
# 0           0        0        0
# 1           0        2        0
# 2           1        0        0
# 3           0        1        2
# 4           1        0        0
# ...       ...      ...      ...
# 41394       0        0        0
# 41395       0        0        0
# 41396       0        0        0
# 41397       0        0        0
# 41398       0        0        0
#
#                                               title_year
# 0      Bugs Bunny's Third Movie: 1001 Rabbit Tales (1...
# 1                       18 anni tra una settimana (1991)
# 2                                Ride a Wild Pony (1976)
# 3                                           Diner (1982)
# 4                 A che servono questi quattrini? (1942)
# ...                                                  ...
# 41394                          Gold Digger Killer (2021)
# 41395                         Addio al nubilato 2 (2023)
# 41396                                 Konferensen (2023)
# 41397                                   Ballelina (2023)
# 41398                   Invitación a un Asesinato (2023)
#
# [41399 rows x 20 columns]

# %% [markdown]
# **Using assign to Create Columns:**
# assign helps you add new columns to a DataFrame in a functional style.

# %%
df = df.assign(
    is_older=lambda x: x['year'] < 2000,
    duration_hours=lambda x: x['duration'] / 60
) # Adding multiple new columns

# %%
df
# Out:
#                                               title  year      genre  \
# 2       Bugs Bunny's Third Movie: 1001 Rabbit Tales  1982  Animation
# 3                         18 anni tra una settimana  1991      Drama
# 17                                 Ride a Wild Pony  1976   Romantic
# 18                                            Diner  1982     Comedy
# 20                  A che servono questi quattrini?  1942     Comedy
# ...                                             ...   ...        ...
# 232817                           Gold Digger Killer  2021   Thriller
# 232893                          Addio al nubilato 2  2023     Comedy
# 232915                                  Konferensen  2023     Horror
# 232919                                    Ballelina  2023   Thriller
# 232920                    Invitación a un Asesinato  2023   Thriller
#
#         duration                country                             directors  \
# 2             76          United States  David Detiege, Art Davis, Bill Perez
# 3             98                  Italy                         Luigi Perelli
# 17            91          United States                           Don Chaffey
# 18            95          United States                        Barry Levinson
# 20            85                  Italy                        Esodo Pratelli
# ...          ...                    ...                                   ...
# 232817        87  Canada, United States                            Robin Hays
# 232893        90                  Italy                    Francesco Apolloni
# 232915       100                 Sweden                         Patrik Eklund
# 232919        92            South Korea                        Chung-Hyun Lee
# 232920        92                 Mexico                          J.M Cravioto
#
#                                                    actors  avg_vote  \
# 2                                                     NaN       7.7
# 3       Kim Rossi Stuart, Simona Cavallari, Ennio Fant...       6.5
# 17      Michael Craig, John Meillon, Eva Griffith, Gra...       5.7
# 18      Mickey Rourke, Steve Guttenberg, Ellen Barkin,...       7.0
# 20      Eduardo De Filippo, Peppino De Filippo, Clelia...       5.9
# ...                                                   ...       ...
# 232817  Julie Benz, Roan Curtis, Georgia Bradner, Eli ...       4.0
# 232893  Laura Chiatti, Chiara Francini, Antonia Liskov...       2.7
# 232915  Katia Winter, Eva Melander, Lola Zackow, Adam ...       6.0
# 232919             Jeon Jong-seo, Park Yu-rim, Ji-hun Kim       5.8
# 232920  Maribel Verdú, Stephanie Cayo, Manolo Cardona,...       6.0
#
#         critics_vote  public_vote  ...  \
# 2               8.00          7.0  ...
# 3               6.00          7.0  ...
# 17              6.00          5.0  ...
# 18              8.00          6.0  ...
# 20              5.33          7.0  ...
# ...              ...          ...  ...
# 232817           NaN          4.0  ...
# 232893           NaN          3.0  ...
# 232915           NaN          6.0  ...
# 232919           NaN          6.0  ...
# 232920           NaN          6.0  ...
#
#                                               description  \
# 2       With two protruding front teeth, a slightly sl...
# 3       Samantha, not yet eighteen, leaves the comfort...
# 17      In the Australia of the pioneers, a boy and a ...
# 18      Five boys from Baltimore have a habit of meeti...
# 20      With a stratagem, the penniless and somewhat p...
# ...                                                   ...
# 232817  Celeste is an attractive waitress in the forti...
# 232893  When Eleonora is downloaded to the altar, her ...
# 232915  A team building conference organized for a gro...
# 232919  Once Ok-Ju worked as a bodyguard and was one o...
# 232920  A great passionate of crime stories is trapped...
#
#                                                     notes humor  rhythm  \
# 2       These are many small independent stories, whic...     3       3
# 3       Luigi Perelli, the director of the "Piovra", o...     0       2
# 17      "Ecological" story with a happy ending, not wi...     1       2
# 18      A cast of will be famous for Levinson's direct...     2       2
# 20      Taken from the play by Armando Curcio that the...     3       1
# ...                                                   ...   ...     ...
# 232817                    Freely taken from a true story.     0       0
# 232893                   Bachelorette fare sequel (2021).     0       0
# 232915                                                NaN     0       0
# 232919                                                NaN     0       0
# 232920                                                NaN     0       0
#
#         effort  tension  erotism  \
# 2            0        0        0
# 3            0        2        0
# 17           1        0        0
# 18           0        1        2
# 20           1        0        0
# ...        ...      ...      ...
# 232817       0        0        0
# 232893       0        0        0
# 232915       0        0        0
# 232919       0        0        0
# 232920       0        0        0
#
#                                                title_year is_older  \
# 2       Bugs Bunny's Third Movie: 1001 Rabbit Tales (1...     True
# 3                        18 anni tra una settimana (1991)     True
# 17                                Ride a Wild Pony (1976)     True
# 18                                           Diner (1982)     True
# 20                 A che servono questi quattrini? (1942)     True
# ...                                                   ...      ...
# 232817                          Gold Digger Killer (2021)    False
# 232893                         Addio al nubilato 2 (2023)    False
# 232915                                 Konferensen (2023)    False
# 232919                                   Ballelina (2023)    False
# 232920                   Invitación a un Asesinato (2023)    False
#
#         duration_hours
# 2             1.266667
# 3             1.633333
# 17            1.516667
# 18            1.583333
# 20            1.416667
# ...                ...
# 232817        1.450000
# 232893        1.500000
# 232915        1.666667
# 232919        1.533333
# 232920        1.533333
#
# [41399 rows x 21 columns]

# %% [markdown]
# # Changing the name of Index
# Pandas allows you to rename the index of a DataFrame or Series, which can help in making the index more informative or aligning it with new data requirements.

# %% [markdown]
# **Renaming the Index of a DataFrame:**

# %%
df.index.names = ['movie_id']  # Renames the index to 'movie_id'

# %%
df
# Out:
#                                                 title  year      genre  \
# movie_id
# 2         Bugs Bunny's Third Movie: 1001 Rabbit Tales  1982  Animation
# 3                           18 anni tra una settimana  1991      Drama
# 17                                   Ride a Wild Pony  1976   Romantic
# 18                                              Diner  1982     Comedy
# 20                    A che servono questi quattrini?  1942     Comedy
# ...                                               ...   ...        ...
# 232817                             Gold Digger Killer  2021   Thriller
# 232893                            Addio al nubilato 2  2023     Comedy
# 232915                                    Konferensen  2023     Horror
# 232919                                      Ballelina  2023   Thriller
# 232920                      Invitación a un Asesinato  2023   Thriller
#
#           duration                country  \
# movie_id
# 2               76          United States
# 3               98                  Italy
# 17              91          United States
# 18              95          United States
# 20              85                  Italy
# ...            ...                    ...
# 232817          87  Canada, United States
# 232893          90                  Italy
# 232915         100                 Sweden
# 232919          92            South Korea
# 232920          92                 Mexico
#
#                                      directors  \
# movie_id
# 2         David Detiege, Art Davis, Bill Perez
# 3                                Luigi Perelli
# 17                                 Don Chaffey
# 18                              Barry Levinson
# 20                              Esodo Pratelli
# ...                                        ...
# 232817                              Robin Hays
# 232893                      Francesco Apolloni
# 232915                           Patrik Eklund
# 232919                          Chung-Hyun Lee
# 232920                            J.M Cravioto
#
#                                                      actors  avg_vote  \
# movie_id
# 2                                                       NaN       7.7
# 3         Kim Rossi Stuart, Simona Cavallari, Ennio Fant...       6.5
# 17        Michael Craig, John Meillon, Eva Griffith, Gra...       5.7
# 18        Mickey Rourke, Steve Guttenberg, Ellen Barkin,...       7.0
# 20        Eduardo De Filippo, Peppino De Filippo, Clelia...       5.9
# ...                                                     ...       ...
# 232817    Julie Benz, Roan Curtis, Georgia Bradner, Eli ...       4.0
# 232893    Laura Chiatti, Chiara Francini, Antonia Liskov...       2.7
# 232915    Katia Winter, Eva Melander, Lola Zackow, Adam ...       6.0
# 232919               Jeon Jong-seo, Park Yu-rim, Ji-hun Kim       5.8
# 232920    Maribel Verdú, Stephanie Cayo, Manolo Cardona,...       6.0
#
#           critics_vote  public_vote  ...  \
# movie_id                             ...
# 2                 8.00          7.0  ...
# 3                 6.00          7.0  ...
# 17                6.00          5.0  ...
# 18                8.00          6.0  ...
# 20                5.33          7.0  ...
# ...                ...          ...  ...
# 232817             NaN          4.0  ...
# 232893             NaN          3.0  ...
# 232915             NaN          6.0  ...
# 232919             NaN          6.0  ...
# 232920             NaN          6.0  ...
#
#                                                 description  \
# movie_id
# 2         With two protruding front teeth, a slightly sl...
# 3         Samantha, not yet eighteen, leaves the comfort...
# 17        In the Australia of the pioneers, a boy and a ...
# 18        Five boys from Baltimore have a habit of meeti...
# 20        With a stratagem, the penniless and somewhat p...
# ...                                                     ...
# 232817    Celeste is an attractive waitress in the forti...
# 232893    When Eleonora is downloaded to the altar, her ...
# 232915    A team building conference organized for a gro...
# 232919    Once Ok-Ju worked as a bodyguard and was one o...
# 232920    A great passionate of crime stories is trapped...
#
#                                                       notes humor  rhythm  \
# movie_id
# 2         These are many small independent stories, whic...     3       3
# 3         Luigi Perelli, the director of the "Piovra", o...     0       2
# 17        "Ecological" story with a happy ending, not wi...     1       2
# 18        A cast of will be famous for Levinson's direct...     2       2
# 20        Taken from the play by Armando Curcio that the...     3       1
# ...                                                     ...   ...     ...
# 232817                      Freely taken from a true story.     0       0
# 232893                     Bachelorette fare sequel (2021).     0       0
# 232915                                                  NaN     0       0
# 232919                                                  NaN     0       0
# 232920                                                  NaN     0       0
#
#           effort  tension  erotism  \
# movie_id
# 2              0        0        0
# 3              0        2        0
# 17             1        0        0
# 18             0        1        2
# 20             1        0        0
# ...          ...      ...      ...
# 232817         0        0        0
# 232893         0        0        0
# 232915         0        0        0
# 232919         0        0        0
# 232920         0        0        0
#
#                                                  title_year is_older  \
# movie_id
# 2         Bugs Bunny's Third Movie: 1001 Rabbit Tales (1...     True
# 3                          18 anni tra una settimana (1991)     True
# 17                                  Ride a Wild Pony (1976)     True
# 18                                             Diner (1982)     True
# 20                   A che servono questi quattrini? (1942)     True
# ...                                                     ...      ...
# 232817                            Gold Digger Killer (2021)    False
# 232893                           Addio al nubilato 2 (2023)    False
# 232915                                   Konferensen (2023)    False
# 232919                                     Ballelina (2023)    False
# 232920                     Invitación a un Asesinato (2023)    False
#
#           duration_hours
# movie_id
# 2               1.266667
# 3               1.633333
# 17              1.516667
# 18              1.583333
# 20              1.416667
# ...                  ...
# 232817          1.450000
# 232893          1.500000
# 232915          1.666667
# 232919          1.533333
# 232920          1.533333
#
# [41399 rows x 21 columns]

# %% [markdown]
# **Renaming Column Indexes:**

# %%
df.rename(columns={'year': 'release_year', 'title': 'movie_title'}, inplace=True)
df
# Out:
#                                           movie_title  release_year  \
# movie_id
# 2         Bugs Bunny's Third Movie: 1001 Rabbit Tales          1982
# 3                           18 anni tra una settimana          1991
# 17                                   Ride a Wild Pony          1976
# 18                                              Diner          1982
# 20                    A che servono questi quattrini?          1942
# ...                                               ...           ...
# 232817                             Gold Digger Killer          2021
# 232893                            Addio al nubilato 2          2023
# 232915                                    Konferensen          2023
# 232919                                      Ballelina          2023
# 232920                      Invitación a un Asesinato          2023
#
#               genre  duration                country  \
# movie_id
# 2         Animation        76          United States
# 3             Drama        98                  Italy
# 17         Romantic        91          United States
# 18           Comedy        95          United States
# 20           Comedy        85                  Italy
# ...             ...       ...                    ...
# 232817     Thriller        87  Canada, United States
# 232893       Comedy        90                  Italy
# 232915       Horror       100                 Sweden
# 232919     Thriller        92            South Korea
# 232920     Thriller        92                 Mexico
#
#                                      directors  \
# movie_id
# 2         David Detiege, Art Davis, Bill Perez
# 3                                Luigi Perelli
# 17                                 Don Chaffey
# 18                              Barry Levinson
# 20                              Esodo Pratelli
# ...                                        ...
# 232817                              Robin Hays
# 232893                      Francesco Apolloni
# 232915                           Patrik Eklund
# 232919                          Chung-Hyun Lee
# 232920                            J.M Cravioto
#
#                                                      actors  avg_vote  \
# movie_id
# 2                                                       NaN       7.7
# 3         Kim Rossi Stuart, Simona Cavallari, Ennio Fant...       6.5
# 17        Michael Craig, John Meillon, Eva Griffith, Gra...       5.7
# 18        Mickey Rourke, Steve Guttenberg, Ellen Barkin,...       7.0
# 20        Eduardo De Filippo, Peppino De Filippo, Clelia...       5.9
# ...                                                     ...       ...
# 232817    Julie Benz, Roan Curtis, Georgia Bradner, Eli ...       4.0
# 232893    Laura Chiatti, Chiara Francini, Antonia Liskov...       2.7
# 232915    Katia Winter, Eva Melander, Lola Zackow, Adam ...       6.0
# 232919               Jeon Jong-seo, Park Yu-rim, Ji-hun Kim       5.8
# 232920    Maribel Verdú, Stephanie Cayo, Manolo Cardona,...       6.0
#
#           critics_vote  public_vote  ...  \
# movie_id                             ...
# 2                 8.00          7.0  ...
# 3                 6.00          7.0  ...
# 17                6.00          5.0  ...
# 18                8.00          6.0  ...
# 20                5.33          7.0  ...
# ...                ...          ...  ...
# 232817             NaN          4.0  ...
# 232893             NaN          3.0  ...
# 232915             NaN          6.0  ...
# 232919             NaN          6.0  ...
# 232920             NaN          6.0  ...
#
#                                                 description  \
# movie_id
# 2         With two protruding front teeth, a slightly sl...
# 3         Samantha, not yet eighteen, leaves the comfort...
# 17        In the Australia of the pioneers, a boy and a ...
# 18        Five boys from Baltimore have a habit of meeti...
# 20        With a stratagem, the penniless and somewhat p...
# ...                                                     ...
# 232817    Celeste is an attractive waitress in the forti...
# 232893    When Eleonora is downloaded to the altar, her ...
# 232915    A team building conference organized for a gro...
# 232919    Once Ok-Ju worked as a bodyguard and was one o...
# 232920    A great passionate of crime stories is trapped...
#
#                                                       notes humor  rhythm  \
# movie_id
# 2         These are many small independent stories, whic...     3       3
# 3         Luigi Perelli, the director of the "Piovra", o...     0       2
# 17        "Ecological" story with a happy ending, not wi...     1       2
# 18        A cast of will be famous for Levinson's direct...     2       2
# 20        Taken from the play by Armando Curcio that the...     3       1
# ...                                                     ...   ...     ...
# 232817                      Freely taken from a true story.     0       0
# 232893                     Bachelorette fare sequel (2021).     0       0
# 232915                                                  NaN     0       0
# 232919                                                  NaN     0       0
# 232920                                                  NaN     0       0
#
#           effort  tension  erotism  \
# movie_id
# 2              0        0        0
# 3              0        2        0
# 17             1        0        0
# 18             0        1        2
# 20             1        0        0
# ...          ...      ...      ...
# 232817         0        0        0
# 232893         0        0        0
# 232915         0        0        0
# 232919         0        0        0
# 232920         0        0        0
#
#                                                  title_year is_older  \
# movie_id
# 2         Bugs Bunny's Third Movie: 1001 Rabbit Tales (1...     True
# 3                          18 anni tra una settimana (1991)     True
# 17                                  Ride a Wild Pony (1976)     True
# 18                                             Diner (1982)     True
# 20                   A che servono questi quattrini? (1942)     True
# ...                                                     ...      ...
# 232817                            Gold Digger Killer (2021)    False
# 232893                           Addio al nubilato 2 (2023)    False
# 232915                                   Konferensen (2023)    False
# 232919                                     Ballelina (2023)    False
# 232920                     Invitación a un Asesinato (2023)    False
#
#           duration_hours
# movie_id
# 2               1.266667
# 3               1.633333
# 17              1.516667
# 18              1.583333
# 20              1.416667
# ...                  ...
# 232817          1.450000
# 232893          1.500000
# 232915          1.666667
# 232919          1.533333
# 232920          1.533333
#
# [41399 rows x 21 columns]

# %% [markdown]
# # Display Options

# %%
# Set maximum number of rows and columns to display
pd.set_option('display.max_rows', 7)
pd.set_option('display.max_columns', 5)

# %%
df
# Out:
#                                           movie_title  release_year  ...  \
# movie_id                                                             ...
# 2         Bugs Bunny's Third Movie: 1001 Rabbit Tales          1982  ...
# 3                           18 anni tra una settimana          1991  ...
# 17                                   Ride a Wild Pony          1976  ...
# ...                                               ...           ...  ...
# 232915                                    Konferensen          2023  ...
# 232919                                      Ballelina          2023  ...
# 232920                      Invitación a un Asesinato          2023  ...
#
#          is_older  duration_hours
# movie_id
# 2            True        1.266667
# 3            True        1.633333
# 17           True        1.516667
# ...           ...             ...
# 232915      False        1.666667
# 232919      False        1.533333
# 232920      False        1.533333
#
# [41399 rows x 21 columns]

# %%
# Reset Options
pd.reset_option('display')

# %%
df
# Out:
#                                           movie_title  release_year  \
# movie_id
# 2         Bugs Bunny's Third Movie: 1001 Rabbit Tales          1982
# 3                           18 anni tra una settimana          1991
# 17                                   Ride a Wild Pony          1976
# 18                                              Diner          1982
# 20                    A che servono questi quattrini?          1942
# ...                                               ...           ...
# 232817                             Gold Digger Killer          2021
# 232893                            Addio al nubilato 2          2023
# 232915                                    Konferensen          2023
# 232919                                      Ballelina          2023
# 232920                      Invitación a un Asesinato          2023
#
#               genre  duration                country  \
# movie_id
# 2         Animation        76          United States
# 3             Drama        98                  Italy
# 17         Romantic        91          United States
# 18           Comedy        95          United States
# 20           Comedy        85                  Italy
# ...             ...       ...                    ...
# 232817     Thriller        87  Canada, United States
# 232893       Comedy        90                  Italy
# 232915       Horror       100                 Sweden
# 232919     Thriller        92            South Korea
# 232920     Thriller        92                 Mexico
#
#                                      directors  \
# movie_id
# 2         David Detiege, Art Davis, Bill Perez
# 3                                Luigi Perelli
# 17                                 Don Chaffey
# 18                              Barry Levinson
# 20                              Esodo Pratelli
# ...                                        ...
# 232817                              Robin Hays
# 232893                      Francesco Apolloni
# 232915                           Patrik Eklund
# 232919                          Chung-Hyun Lee
# 232920                            J.M Cravioto
#
#                                                      actors  avg_vote  \
# movie_id
# 2                                                       NaN       7.7
# 3         Kim Rossi Stuart, Simona Cavallari, Ennio Fant...       6.5
# 17        Michael Craig, John Meillon, Eva Griffith, Gra...       5.7
# 18        Mickey Rourke, Steve Guttenberg, Ellen Barkin,...       7.0
# 20        Eduardo De Filippo, Peppino De Filippo, Clelia...       5.9
# ...                                                     ...       ...
# 232817    Julie Benz, Roan Curtis, Georgia Bradner, Eli ...       4.0
# 232893    Laura Chiatti, Chiara Francini, Antonia Liskov...       2.7
# 232915    Katia Winter, Eva Melander, Lola Zackow, Adam ...       6.0
# 232919               Jeon Jong-seo, Park Yu-rim, Ji-hun Kim       5.8
# 232920    Maribel Verdú, Stephanie Cayo, Manolo Cardona,...       6.0
#
#           critics_vote  public_vote  ...  \
# movie_id                             ...
# 2                 8.00          7.0  ...
# 3                 6.00          7.0  ...
# 17                6.00          5.0  ...
# 18                8.00          6.0  ...
# 20                5.33          7.0  ...
# ...                ...          ...  ...
# 232817             NaN          4.0  ...
# 232893             NaN          3.0  ...
# 232915             NaN          6.0  ...
# 232919             NaN          6.0  ...
# 232920             NaN          6.0  ...
#
#                                                 description  \
# movie_id
# 2         With two protruding front teeth, a slightly sl...
# 3         Samantha, not yet eighteen, leaves the comfort...
# 17        In the Australia of the pioneers, a boy and a ...
# 18        Five boys from Baltimore have a habit of meeti...
# 20        With a stratagem, the penniless and somewhat p...
# ...                                                     ...
# 232817    Celeste is an attractive waitress in the forti...
# 232893    When Eleonora is downloaded to the altar, her ...
# 232915    A team building conference organized for a gro...
# 232919    Once Ok-Ju worked as a bodyguard and was one o...
# 232920    A great passionate of crime stories is trapped...
#
#                                                       notes humor  rhythm  \
# movie_id
# 2         These are many small independent stories, whic...     3       3
# 3         Luigi Perelli, the director of the "Piovra", o...     0       2
# 17        "Ecological" story with a happy ending, not wi...     1       2
# 18        A cast of will be famous for Levinson's direct...     2       2
# 20        Taken from the play by Armando Curcio that the...     3       1
# ...                                                     ...   ...     ...
# 232817                      Freely taken from a true story.     0       0
# 232893                     Bachelorette fare sequel (2021).     0       0
# 232915                                                  NaN     0       0
# 232919                                                  NaN     0       0
# 232920                                                  NaN     0       0
#
#           effort  tension  erotism  \
# movie_id
# 2              0        0        0
# 3              0        2        0
# 17             1        0        0
# 18             0        1        2
# 20             1        0        0
# ...          ...      ...      ...
# 232817         0        0        0
# 232893         0        0        0
# 232915         0        0        0
# 232919         0        0        0
# 232920         0        0        0
#
#                                                  title_year is_older  \
# movie_id
# 2         Bugs Bunny's Third Movie: 1001 Rabbit Tales (1...     True
# 3                          18 anni tra una settimana (1991)     True
# 17                                  Ride a Wild Pony (1976)     True
# 18                                             Diner (1982)     True
# 20                   A che servono questi quattrini? (1942)     True
# ...                                                     ...      ...
# 232817                            Gold Digger Killer (2021)    False
# 232893                           Addio al nubilato 2 (2023)    False
# 232915                                   Konferensen (2023)    False
# 232919                                     Ballelina (2023)    False
# 232920                     Invitación a un Asesinato (2023)    False
#
#           duration_hours
# movie_id
# 2               1.266667
# 3               1.633333
# 17              1.516667
# 18              1.583333
# 20              1.416667
# ...                  ...
# 232817          1.450000
# 232893          1.500000
# 232915          1.666667
# 232919          1.533333
# 232920          1.533333
#
# [41399 rows x 21 columns]

# %% [markdown]
# # Grouping Data:
# Grouping data is a powerful way to perform segment-wise analysis and break down the dataset into chunks based on some criteria.

# %%
genre_groups = df.groupby('genre')  # Groups the data by the 'genre' column
genre_groups

# %%
for genre, group_data in genre_groups:
    print(f"Genre: {genre}")
    print(group_data)
    print()
# Out:
# Genre: Action
#                    movie_title  release_year   genre  duration        country  \
# movie_id
# 38                Mr. Majestyk          1974  Action       105  United States
# 45                Warning Sign          1985  Action        99  United States
# 193                Airport '77          1977  Action       110  United States
# 530        Wings of the Apache          1990  Action        86  United States
# 574       Geheimcode Wildgänse          1985  Action        93          Italy
# ...                        ...           ...     ...       ...            ...
# 225561      Tin joek yau ching          1990  Action        87      Hong Kong
# 226116            Blood & Gold          2023  Action       100        Germany
# 228408            Kung Fu Girl          2021  Action        98  United States
# 229097                 Hit Man          2023  Action       113  United States
# 231061              Sentinelle          2023  Action        99         France
#
#                                  directors  \
# movie_id
# 38                       Richard Fleischer
# 45                             Hal Barwood
# 193                          Jerry Jameson
# 530                            David Green
# 574                     Antonio Margheriti
# ...                                    ...
# 225561                          Benny Chan
# 226116                     Peter Thorwarth
# 228408             Devon Downs, Kenny Gage
# 229097                   Richard Linklater
# 231061    Hugo Benamozig, David Caviglioli
#
#                                                      actors  avg_vote  \
# movie_id
# 38        Charles Bronson, Linda Cristal, Al Lettieri, L...       6.2
# 45        Sam Waterston, Kathleen Quinlan, Yaphet Kotto,...       4.8
# 193       Jack Lemmon, James Stewart, Lee Grant, Brenda ...       4.7
# 530       Nicolas Cage, Sean Young, Tommy Lee Jones, Dal...       4.6
# 574       Lewis Collins, Lee Van Cleef, Ernest Borgnine,...       4.9
# ...                                                     ...       ...
# 225561    Andy Lau, Chien-lien Wu, Man-Tat Ng, Kwong-Leu...       7.5
# 226116    Jördis Triebel, Alexander Scheer, Robert Maase...       6.1
# 228408    Danny Kwok-Kwan Chan, Yixi Tao, Shuting Li, Xi...       4.5
# 229097    Adria Arjona, Glen Powell, Retta, Austin Ameli...       7.1
# 231061    Jonathan Cohen, Emmanuelle Bercot, Raphaël Que...       4.0
#
#           critics_vote  public_vote  ...  \
# movie_id                             ...
# 38                5.71          7.0  ...
# 45                4.00          6.0  ...
# 193               3.33          6.0  ...
# 530               4.00          5.0  ...
# 574               3.50          6.0  ...
# ...                ...          ...  ...
# 225561            7.00          8.0  ...
# 226116            5.67          7.0  ...
# 228408             NaN          5.0  ...
# 229097            7.00          7.0  ...
# 231061             NaN          4.0  ...
#
#                                                 description  \
# movie_id
# 38        A veteran of Vietnam, Vince (Bronson) grows me...
# 45        Inside the Biotek laboratory, a renowned and r...
# 193       An elderly billionaire, on the occasion of an ...
# 530       Jake Preston, a helicopter pilot, is called to...
# 574       Captain Wesley (Lewis Collins), whose son died...
# ...                                                     ...
# 225561    During a bank robbery, the driver designated f...
# 226116    Spring of 1945, the last days of the Second Wo...
# 228408    The twelve year old Lisa suffers from the scho...
# 229097    Gary Johnson, police investigator, plays under...
# 231061    François Sentinelle leads a double life. Durin...
#
#                                                       notes humor  rhythm  \
# movie_id
# 38        Cliché screenplay (by Elmore Leonard) tailored...     0       4
# 45        It is a film that mixes "The invasion of the b...     0       2
# 193       The film is yet another variation on the catas...     0       2
# 530       Nothing to say about Nicolas Cage as a drug ag...     1       2
# 574                                                     NaN     0       2
# ...                                                     ...   ...     ...
# 225561                                                  NaN     0       0
# 226116                                                  NaN     0       0
# 228408                                                  NaN     0       0
# 229097                                                  NaN     0       0
# 231061                                                  NaN     0       0
#
#           effort  tension  erotism                   title_year is_older  \
# movie_id
# 38             3        3        0          Mr. Majestyk (1974)     True
# 45             1        1        0          Warning Sign (1985)     True
# 193            0        1        0           Airport '77 (1977)     True
# 530            0        1        1   Wings of the Apache (1990)     True
# 574            0        2        0  Geheimcode Wildgänse (1985)     True
# ...          ...      ...      ...                          ...      ...
# 225561         0        0        0    Tin joek yau ching (1990)     True
# 226116         0        0        0          Blood & Gold (2023)    False
# 228408         0        0        0          Kung Fu Girl (2021)    False
# 229097         0        0        0               Hit Man (2023)    False
# 231061         0        0        0            Sentinelle (2023)    False
#
#           duration_hours
# movie_id
# 38              1.750000
# 45              1.650000
# 193             1.833333
# 530             1.433333
# 574             1.550000
# ...                  ...
# 225561          1.450000
# 226116          1.666667
# 228408          1.633333
# 229097          1.883333
# 231061          1.650000
#
# [2155 rows x 21 columns]
#
# Genre: Adventure
#                                movie_title  release_year      genre  duration  \
# movie_id
# 30               A Ghentar si muore facile          1968  Adventure       101
# 53                      A qualsiasi prezzo          1968  Adventure        94
# 74                                The Deep          1977  Adventure       130
# 145                         Africa Express          1975  Adventure        95
# 146                    Africa sotto i mari          1952  Adventure        95
# ...                                    ...           ...        ...       ...
# 222074                     We Have a Ghost          2023  Adventure       126
# 222398            Tremors: Shrieker Island          2020  Adventure       103
# 224588               Knights of the Zodiac          2023  Adventure       112
# 225497    Coast Guard Malaysia: Ops Helang          2023  Adventure        90
# 227960                       Hidden Strike          2023  Adventure       102
#
#                                 country           directors  \
# movie_id
# 30                                Italy      Leon Klimovsky
# 53                                Italy     Emilio Miraglia
# 74                        United States         Peter Yates
# 145                               Italy        Michele Lupo
# 146                               Italy   Giovanni Roccardi
# ...                                 ...                 ...
# 222074                    United States  Christopher Landon
# 222398                    United States    Don Michael Paul
# 224588    Japan, Hungary, United States     Tomasz Baginski
# 225497                         Malaysia          Pitt Hanif
# 227960             China, United States         Scott Waugh
#
#                                                      actors  avg_vote  \
# movie_id
# 30        George Hilton, Ennio Girolami, Marta Padovan, ...       4.8
# 53        Walter Pidgeon, Ira Fürstenberg, Klaus Kinski,...       3.8
# 74        Nick Nolte, Jacqueline Bisset, Robert Shaw, El...       5.3
# 145       Giuliano Gemma, Ursula Andress, Jack Palance, ...       5.1
# 146       Sophia Loren, Stephen Barclay, Umberto Melnati...       4.1
# ...                                                     ...       ...
# 222074    Jennifer Coolidge, David Harbour, Anthony Mack...       6.2
# 222398    Michael Gross, Jon Heder, Richard Brake, Carol...       5.6
# 224588    Famke Janssen, Sean Bean, Madison Iseman, Mark...       3.4
# 225497    Saharul Ridzwan, Julia Farhana Marin, Sabri Yu...       3.5
# 227960    Jackie Chan, John Cena, Pilou Asbæk, Rachael H...       6.0
#
#           critics_vote  public_vote  ...  \
# movie_id                             ...
# 30                4.50          5.0  ...
# 53                4.00          4.0  ...
# 74                4.88          6.0  ...
# 145               5.50          5.0  ...
# 146               4.00          4.0  ...
# ...                ...          ...  ...
# 222074            6.00          6.0  ...
# 222398            5.00          6.0  ...
# 224588            3.00          4.0  ...
# 225497            3.00          4.0  ...
# 227960             NaN          6.0  ...
#
#                                                 description  \
# movie_id
# 30        An adventurer juggles a dictator and a group o...
# 53        The holidays of Professor Cummings, an illustr...
# 74        A boy and a girl, passionate divers, dive off ...
# 145       John Baxter (Gemma) has been working in Africa...
# 146       In the Red Sea, a group of men is engaged in a...
# ...                                                     ...
# 222074    Kevin and his family suddenly become famous on...
# 222398    The adventurous entrepreneur Bill - together w...
# 224588    When a goddess of the war reincarnates in the ...
# 225497    Hafiz, the Malaysian Coast Guard officer, cele...
# 227960    In the near future, a group of civilians is fo...
#
#                                                       notes humor  rhythm  \
# movie_id
# 30                                                      NaN     0       2
# 53        Although Emilio Miraglia is blind (in cinemati...     1       2
# 74        Not very exciting, but the underwater scenes a...     1       2
# 145       The film had a notable success with the public...     1       2
# 146       Except for the presence of Sophia Loren, the b...     0       1
# ...                                                     ...   ...     ...
# 222074                                                  NaN     0       0
# 222398                                                  NaN     0       0
# 224588                                                  NaN     1       1
# 225497                                                  NaN     0       0
# 227960                                                  NaN     0       0
#
#           effort  tension  erotism                               title_year  \
# movie_id
# 30             0        1        0         A Ghentar si muore facile (1968)
# 53             0        1        1                A qualsiasi prezzo (1968)
# 74             1        2        1                          The Deep (1977)
# 145            0        1        1                    Africa Express (1975)
# 146            0        1        2               Africa sotto i mari (1952)
# ...          ...      ...      ...                                      ...
# 222074         0        0        0                   We Have a Ghost (2023)
# 222398         0        0        0          Tremors: Shrieker Island (2020)
# 224588         0        0        0             Knights of the Zodiac (2023)
# 225497         0        0        0  Coast Guard Malaysia: Ops Helang (2023)
# 227960         0        0        0                     Hidden Strike (2023)
#
#          is_older  duration_hours
# movie_id
# 30           True        1.683333
# 53           True        1.566667
# 74           True        2.166667
# 145          True        1.583333
# 146          True        1.583333
# ...           ...             ...
# 222074      False        2.100000
# 222398      False        1.716667
# 224588      False        1.866667
# 225497      False        1.500000
# 227960      False        1.700000
#
# [1524 rows x 21 columns]
#
# Genre: Animation
#                                           movie_title  release_year  \
# movie_id
# 2         Bugs Bunny's Third Movie: 1001 Rabbit Tales          1982
# 260                              The Land Before Time          1988
# 271                                Allegro non troppo          1977
# 679                      Asterix et le coup de menhir          1989
# 1093                               The Secret Of Nimh          1982
# ...                                               ...           ...
# 223768    Teenage Mutant Ninja Turtles: Mutant Mayhem          2023
# 223769                            The First Slam Dunk          2022
# 224224                   Ruby Gillman, Teenage Kraken          2023
# 229395                    Lonely Castle in the Mirror          2022
# 229825                                        Invelle          2023
#
#               genre  duration        country  \
# movie_id
# 2         Animation        76  United States
# 260       Animation        79  United States
# 271       Animation        85          Italy
# 679       Animation        81         France
# 1093      Animation        82  United States
# ...             ...       ...            ...
# 223768    Animation        99  United States
# 223769    Animation       124          Japan
# 224224    Animation        91  United States
# 229395    Animation       116          Japan
# 229825    Animation        96          Italy
#
#                                      directors  \
# movie_id
# 2         David Detiege, Art Davis, Bill Perez
# 260                                  Don Bluth
# 271                             Bruno Bozzetto
# 679                           Philippe Grimond
# 1093                                 Don Bluth
# ...                                        ...
# 223768                 Jeff Rowe, Kyler Spears
# 223769          Takehiko Inoue, Yasuyuki Ebara
# 224224                            Kirk DeMicco
# 229395         Keiichi Hara, Takakazu Nagatomo
# 229825                            Simone Massi
#
#                                                      actors  avg_vote  \
# movie_id
# 2                                                       NaN       7.7
# 260                                                     NaN       7.4
# 271       Maurizio Nichetti, Maurizio Micheli, Maria Lui...       7.6
# 679                                                     NaN       6.8
# 1093                                                    NaN       8.2
# ...                                                     ...       ...
# 223768                                                  NaN       6.4
# 223769                                                  NaN       8.0
# 224224                                                  NaN       6.0
# 229395                                                  NaN       6.7
# 229825                                                  NaN       9.0
#
#           critics_vote  public_vote  ...  \
# movie_id                             ...
# 2                 8.00          7.0  ...
# 260               7.50          7.0  ...
# 271               7.71          8.0  ...
# 679               6.67          7.0  ...
# 1093              8.50          8.0  ...
# ...                ...          ...  ...
# 223768            6.50          6.0  ...
# 223769             NaN          8.0  ...
# 224224            7.00          5.0  ...
# 229395            6.50          7.0  ...
# 229825            8.50         10.0  ...
#
#                                                 description  \
# movie_id
# 2         With two protruding front teeth, a slightly sl...
# 260       A group of herbivorous dinosaurs of the "Colli...
# 271       A director wants to make an animated film base...
# 679       In Gaul subjugated by the Romans only the vill...
# 1093      Brisby, a widowed mouse, lives in a field with...
# ...                                                     ...
# 223768    After years spent in the sewers hiding from hu...
# 223769    Ryota Miyagi has an older, sota, three -year -...
# 224224    A shy teenager discovers that he comes from a ...
# 229395    In a quiet district of Tokyo, seven students j...
# 229825    1918. Zelinda is a peasant child orphaned moth...
#
#                                                       notes humor  rhythm  \
# movie_id
# 2         These are many small independent stories, whic...     3       3
# 260       With Ralph Bakshi, Don Bluth (who actually cut...     3       3
# 271       Debussy's "Prelude to the afternoon of a faun"...     2       3
# 679                                                     NaN     3       3
# 1093      After a long experience at Disney, Don Bluth w...     2       2
# ...                                                     ...   ...     ...
# 223768                                                  NaN     0       0
# 223769           Based on Takehiko Inoue's Slam Dunk manga.     0       0
# 224224                                                  NaN     0       0
# 229395                                                  NaN     0       0
# 229825                                                  NaN     0       0
#
#           effort  tension  erotism  \
# movie_id
# 2              0        0        0
# 260            0        1        0
# 271            2        0        0
# 679            0        0        0
# 1093           0        2        0
# ...          ...      ...      ...
# 223768         0        0        0
# 223769         0        0        0
# 224224         0        0        0
# 229395         1        1        1
# 229825         0        0        0
#
#                                                  title_year is_older  \
# movie_id
# 2         Bugs Bunny's Third Movie: 1001 Rabbit Tales (1...     True
# 260                             The Land Before Time (1988)     True
# 271                               Allegro non troppo (1977)     True
# 679                     Asterix et le coup de menhir (1989)     True
# 1093                              The Secret Of Nimh (1982)     True
# ...                                                     ...      ...
# 223768    Teenage Mutant Ninja Turtles: Mutant Mayhem (2...    False
# 223769                           The First Slam Dunk (2022)    False
# 224224                  Ruby Gillman, Teenage Kraken (2023)    False
# 229395                   Lonely Castle in the Mirror (2022)    False
# 229825                                       Invelle (2023)    False
#
#           duration_hours
# movie_id
# 2               1.266667
# 260             1.316667
# 271             1.416667
# 679             1.350000
# 1093            1.366667
# ...                  ...
# 223768          1.650000
# 223769          2.066667
# 224224          1.516667
# 229395          1.933333
# 229825          1.600000
#
# [1076 rows x 21 columns]
#
# Genre: Biblical
#                                  movie_title  release_year     genre  \
# movie_id
# 942                                  Ben Hur          1959  Biblical
# 2119                    The Ten Commandments          1956  Biblical
# 2531                         Erode il Grande          1958  Biblical
# 3151                     Giuditta e Oloferne          1958  Biblical
# 3167           Giuseppe venduto dai fratelli          1961  Biblical
# 4274                               Il Messia          1975  Biblical
# 5347            The Greatest Story Ever Told          1965  Biblical
# 5854                       The King of Kings          1961  Biblical
# 6677                     La spada e la croce          1959  Biblical
# 6836                       The Story of Ruth          1960  Biblical
# 7372                                The Robe          1953  Biblical
# 9031                       Solomon and Sheba          1959  Biblical
# 10368                          David e Golia          1959  Biblical
# 12762     Genesi - La Creazione e il Diluvio          1994  Biblical
# 12825                          Ester e il re          1960  Biblical
# 16849                                 Esther          1985  Biblical
# 17935                           Il quarto re          1997  Biblical
# 19554                        Maria Maddalena          2000  Biblical
# 21090                                  Giuda          2000  Biblical
# 21135                                Tommaso          2001  Biblical
# 21910                   Giuseppe di Nazareth          1999  Biblical
# 24080             San Giovanni. L'Apocalisse          2002  Biblical
# 26238                             Noah's Ark          1999  Biblical
# 26341              The Passion of the Christ          2004  Biblical
# 35707                       Gesù di Nazareth          1977  Biblical
# 42350                       Viaggiu dulurusu          1992  Biblical
# 42430                      The King of Kings          1927  Biblical
# 51072                                 Salome          1922  Biblical
# 51481                       Maria di Nazaret          2012  Biblical
# 54251                                Ben Hur          2010  Biblical
# 56046                               Jeremiah          1998  Biblical
# 58832                             San Pietro          2005  Biblical
# 60587                                Solomon          1997  Biblical
# 61169                      Paul the Apostole          2000  Biblical
# 65370                             Son of God          2014  Biblical
# 76154                     Samson and Delilah          1996  Biblical
# 76434                                  David          1997  Biblical
# 150491                                Samson          2018  Biblical
#
#           duration                                            country  \
# movie_id
# 942            212                                      United States
# 2119           220                                      United States
# 2531            95                                              Italy
# 3151            94                                              Italy
# 3167           102                                  Italy, Yugoslavia
# 4274           140                                      Italy, France
# 5347           200                                      United States
# 5854           168                                      United States
# 6677           106                                              Italy
# 6836           132                                      United States
# 7372           135                                      United States
# 9031           120                                      United States
# 10368          113                                              Italy
# 12762          101                                              Italy
# 12825          109                                              Italy
# 16849           90                              Israel, Great Britain
# 17935           90                                              Italy
# 19554           93                                              Italy
# 21090           90                                              Italy
# 21135           90                                              Italy
# 21910           96                                     Italy, Germany
# 24080          130                                              Italy
# 26238          130                             United States, Germany
# 26341          126                                      United States
# 35707          371                                              Italy
# 42350           41                                              Italy
# 42430          112                                      United States
# 51072           72                                      United States
# 51481          200                              Italy, Germany, Spain
# 54251          180              Great Britain, Germany, Spain, Canada
# 56046           90                      Italy, Germany, United States
# 58832          200                                              Italy
# 60587          180  Great Britain, Czech Republic, France, Italy, ...
# 61169          170                     Italy, Czech Republic, Germany
# 65370          138                                      United States
# 76154          172                      Germany, Italy, United States
# 76434          190                      United States, Italy, Germany
# 150491         116                                      United States
#
#                                   directors  \
# movie_id
# 942                           William Wyler
# 2119                       Cecil B. DeMille
# 2531                        Arnaldo Genoino
# 3151                       Fernando Cerchio
# 3167                          Irving Rapper
# 4274                     Roberto Rossellini
# 5347                         George Stevens
# 5854                           Nicholas Ray
# 6677               Carlo Ludovico Bragaglia
# 6836                           Henry Koster
# 7372                           Henry Koster
# 9031                             King Vidor
# 10368     Ferdinando Baldi, Richard Pottier
# 12762                          Ermanno Olmi
# 12825               Raoul Walsh, Mario Bava
# 16849                            Amos Gitai
# 17935                         Stefano Reali
# 19554                       Raffaele Mertes
# 21090                       Raffaele Mertes
# 21135                       Raffaele Mertes
# 21910                       Raffaele Mertes
# 24080                       Raffaele Mertes
# 26238                            John Irvin
# 26341                            Mel Gibson
# 35707                     Franco Zeffirelli
# 42350                      Pasquale Scimeca
# 42430                      Cecil B. DeMille
# 51072                        Charles Bryant
# 51481                     Giacomo Campiotti
# 54251                           Steve Shill
# 56046                           Harry Winer
# 58832                           Giulio Base
# 60587                           Roger Young
# 61169                           Roger Young
# 65370                   Christopher Spencer
# 76154                          Nicolas Roeg
# 76434                      Robert Markowitz
# 150491     Bruce Macdonald, Gabriel Sabloff
#
#                                                      actors  avg_vote  \
# movie_id
# 942       Charlton Heston, Stephen Boyd, Jack Hawkins, H...       8.1
# 2119      Charlton Heston, Yul Brynner, Anne Baxter, Edw...       8.2
# 2531      Edmund Purdom, Sylvia Lopez, Massimo Girotti, ...       4.6
# 3151      Massimo Girotti, Isabelle Corey, Renato Baldin...       4.1
# 3167      Geoffrey Horne, Robert Morley, Belinda Lee, Te...       5.2
# 4274      Pier Maria Rossi, Mita Ungaro, Carlos de Carva...       6.3
# 5347      Max Von Sydow, Dorothy McGuire, Charlton Hesto...       5.6
# 5854      Jeffrey Hunter, Robert Ryan, Siobhan McKenna, ...       6.5
# 6677      Yvonne De Carlo, Jorge Mistral, Massimo Serato...       3.9
# 6836      Elana Eden, Stuart Whitman, Tom Tryon, Peggy W...       5.4
# 7372      Richard Burton, Jean Simmons, Victor Mature, M...       6.1
# 9031      Yul Brynner, Gina Lollobrigida, George Sanders...       6.1
# 10368     Orson Welles, Eleonora Rossi Drago, Massimo Se...       4.7
# 12762            Omero Antonutti, Attori non professionisti       4.8
# 12825     Joan Collins, Richard Egan, Daniela Rocca, Ser...       4.5
# 16849     Mohammed Bakri, Simone Benyamini, Juliano Mer-...       6.8
# 17935     Raoul Bova, Maria Grazia Cucinotta, Daniel Cec...       4.4
# 19554     Maria Grazia Cucinotta, Manolo Arias, Roberta ...       3.8
# 21090     Enrico Lo Verso, Danny Quinn, Mathieu Carrière...       4.8
# 21135     Ricky Tognazzi, Hannes Jaenicke, Maria Grazia ...       3.1
# 21910     Tobias Moretti, Ennio Fantastichini, Renato Sc...       3.9
# 24080     Richard Harris, Vittoria Belvedere, Benjamin S...       5.0
# 26238     Jon Voight, Mary Steenburgen, F. Murray Abraha...       5.0
# 26341     Jim Caviezel, Monica Bellucci, Claudia Gerini,...       5.9
# 35707     Robert Powell, Anne Bancroft, Ernest Borgnine,...       5.9
# 42350                   Sergio Albertini, Patrizia Giordano       6.0
# 42430     H.B. Warner, Dorothy Cumming, Ernest Torrence,...       6.6
# 51072     Alla Nazimova, Mitchell Lewis, Rose Dione, Nig...       7.7
# 51481     Alissa Jung, Paz Vega, Andreas Pietschmann, An...       5.0
# 54251     Joseph Morgan, Stephen Campbell Moore, Emily V...       2.9
# 56046     Patrick Dempsey, Oliver Reed, Klaus Maria Bran...       5.0
# 58832     Omar Sharif, Daniele Pecci, Flavio Insinna, Cl...       3.8
# 60587     Ben Cross, Anouk Aimée, Vivica A. Fox, Max Von...       5.5
# 61169     Johannes Brandrup, Thomas Lockyer, Barbora Bob...       4.5
# 65370     Diogo Morgado, Roma Downey, Louise Delamere, A...       4.8
# 76154     Eric Thal, Elizabeth Hurley, Michael Gambon, D...       4.7
# 76434     Nathaniel Parker, Jonathan Pryce, Leonard Nimo...       3.3
# 150491    Taylor James, Jackson Rathbone, Billy Zane, Ru...       4.5
#
#           critics_vote  public_vote  ...  \
# movie_id                             ...
# 942               8.25          8.0  ...
# 2119              8.21          8.0  ...
# 2531              4.50          5.0  ...
# 3151              3.00          5.0  ...
# 3167              5.00          5.0  ...
# 4274              7.25          5.0  ...
# 5347              5.75          5.0  ...
# 5854              6.29          7.0  ...
# 6677              4.25          3.0  ...
# 6836              4.67          6.0  ...
# 7372              6.00          6.0  ...
# 9031              5.50          7.0  ...
# 10368             5.00          4.0  ...
# 12762             4.75          5.0  ...
# 12825             4.00          5.0  ...
# 16849             8.00          6.0  ...
# 17935             4.00          5.0  ...
# 19554             4.00          4.0  ...
# 21090             4.50          5.0  ...
# 21135             3.67          3.0  ...
# 21910             4.00          4.0  ...
# 24080             5.00          5.0  ...
# 26238             6.00          4.0  ...
# 26341             5.53          6.0  ...
# 35707             4.88          7.0  ...
# 42350             6.33          6.0  ...
# 42430             6.00          7.0  ...
# 51072              NaN          8.0  ...
# 51481             4.00          6.0  ...
# 54251             2.50          3.0  ...
# 56046             4.00          6.0  ...
# 58832             3.50          4.0  ...
# 60587              NaN          6.0  ...
# 61169              NaN          5.0  ...
# 65370              NaN          5.0  ...
# 76154             4.00          5.0  ...
# 76434              NaN          3.0  ...
# 150491            4.00          5.0  ...
#
#                                                 description  \
# movie_id
# 942       The centurion Messala and the Jewish nobleman ...
# 2119      Having escaped the massacre of the Jewish firs...
# 2531      Herod, king of Judea, rules with violence and ...
# 3151      The Babylonian general Holofernes conquers and...
# 3167      Joseph, one of the twelve sons of the patriarc...
# 4274      The history of the Jewish people and the arriv...
# 5347      The life of Christ is retraced entirely and wi...
# 5854      The film begins with the birth of Jesus, in th...
# 6677      In Pontius Pilate's Palestine, Maria di Magdal...
# 6836      Ruth, priestess of the Chemosh cult, goes into...
# 7372      The tribune Marcello is sent to Palestine. Thu...
# 9031      Dying King David chooses Solomon as his succes...
# 10368     David is introduced to the court of Saul, in c...
# 12762     A nomadic shepherd tells his offspring gathere...
# 12825     Esther (Collins) is beautiful, young, Jewish a...
# 16849     Esther is the biblical heroine mentioned in th...
# 17935     Alazhar is a passionate beekeeper peasant and ...
# 19554     A young and beautiful Jewish peasant, Mary Mag...
# 21090     In Jerusalem, with the Easter feast approachin...
# 21135     Thomas, a disciple of Jesus, wants to give a w...
# 21910     Joseph, belonging to the dynasty of David, is ...
# 24080     Year 90 d. C .: terrified by the ultimatum pro...
# 26238     The destruction of Sodoma and Gomorra, inhabit...
# 26341     The last twelve hours of Jesus' life: from the...
# 35707     The story of the life of Jesus Christ as hande...
# 42350     Mary and Joseph undertake the journey to Bethl...
# 42430     Mary Magdalene is giving a banquet which Judas...
# 51072     At the court of the tetrarch king of Galilee H...
# 51481     Maria (Alissa Jung) is a sweet, sensitive and ...
# 54251     A Jew, in 1st century AD Palestine, is accused...
# 56046     The story of the prophet Jeremiah is one of th...
# 58832     After Jesus' death, Peter has on his shoulders...
# 60587     David, now old, is still king of Israel when, ...
# 61169     The story of the conversion of Saul of Tarsus,...
# 65370     The story of the life of Jesus, told from birt...
# 76154     Samson, a simple shepherd of prodigious streng...
# 76434     David defeating the invincible Goliath, become...
# 150491    Samson, a Jew with unusual physical strength, ...
#
#                                                       notes humor  rhythm  \
# movie_id
# 942       The film is certainly one of the greatest cine...     1       3
# 2119      The film has become the quintessential example...     1       3
# 2531                                                    NaN     0       2
# 3151                                                    NaN     0       2
# 3167                                                    NaN     0       2
# 4274                                                    NaN     0       2
# 5347                                                    NaN     0       2
# 5854                                                    NaN     0       2
# 6677                                                    NaN     0       2
# 6836                                                    NaN     0       2
# 7372      Meatloaf of enormous commitment and enormous s...     0       2
# 9031      An unlikely and expensive classic peplum, it i...     1       2
# 10368     A production assembled with a discreet wealth ...     0       2
# 12762     Entrusted to the "poetry" of a Ermanno Olmi, w...     0       1
# 12825                                                   NaN     0       2
# 16849     In this film, the director Amos Gitai reinterp...     0       2
# 17935                                                   NaN     0       2
# 19554                                                   NaN     0       2
# 21090                                                   NaN     0       2
# 21135                                                   NaN     0       2
# 21910                                                   NaN     0       2
# 24080                                                   NaN     0       1
# 26238                                                   NaN     1       2
# 26341     The _Passion of Christ_ is - without sin of bl...     0       1
# 35707     A six-hour illustration of the Gospel texts. T...     0       2
# 42350     Scimeca's work is strongly linked to literatur...     0       1
# 42430     Majestic representation of the Gospels by the ...     0       2
# 51072     First feature film on the myth of Salomè, prod...     0       0
# 51481                                                   NaN     0       0
# 54251     Miniseries condensed into a grueling and ridic...     0       2
# 56046                                                   NaN     0       2
# 58832     Television biography of St. Peter, based on th...     0       0
# 60587                                                   NaN     0       0
# 61169                                                   NaN     0       0
# 65370     Film version of the episodes of the History Ch...     0       2
# 76154                                                   NaN     0       0
# 76434                                                   NaN     0       0
# 150491                                                  NaN     0       0
#
#           effort  tension  erotism                                 title_year  \
# movie_id
# 942            2        3        1                             Ben Hur (1959)
# 2119           3        3        2                The Ten Commandments (1956)
# 2531           1        1        1                     Erode il Grande (1958)
# 3151           0        1        0                 Giuditta e Oloferne (1958)
# 3167           0        2        1       Giuseppe venduto dai fratelli (1961)
# 4274           4        1        0                           Il Messia (1975)
# 5347           2        1        0        The Greatest Story Ever Told (1965)
# 5854           2        2        0                   The King of Kings (1961)
# 6677           0        2        1                 La spada e la croce (1959)
# 6836           0        1        0                   The Story of Ruth (1960)
# 7372           1        2        0                            The Robe (1953)
# 9031           0        1        1                   Solomon and Sheba (1959)
# 10368          2        2        1                       David e Golia (1959)
# 12762          1        1        0  Genesi - La Creazione e il Diluvio (1994)
# 12825          2        2        1                       Ester e il re (1960)
# 16849          3        2        0                              Esther (1985)
# 17935          0        1        0                        Il quarto re (1997)
# 19554          0        2        0                     Maria Maddalena (2000)
# 21090          2        2        0                               Giuda (2000)
# 21135          0        1        0                             Tommaso (2001)
# 21910          1        1        0                Giuseppe di Nazareth (1999)
# 24080          3        1        0          San Giovanni. L'Apocalisse (2002)
# 26238          0        1        0                          Noah's Ark (1999)
# 26341          4        2        0           The Passion of the Christ (2004)
# 35707          3        1        1                    Gesù di Nazareth (1977)
# 42350          3        0        0                    Viaggiu dulurusu (1992)
# 42430          0        2        0                   The King of Kings (1927)
# 51072          0        0        0                              Salome (1922)
# 51481          0        0        0                    Maria di Nazaret (2012)
# 54251          0        1        0                             Ben Hur (2010)
# 56046          2        2        0                            Jeremiah (1998)
# 58832          0        0        0                          San Pietro (2005)
# 60587          0        0        0                             Solomon (1997)
# 61169          0        0        0                   Paul the Apostole (2000)
# 65370          0        1        0                          Son of God (2014)
# 76154          0        0        0                  Samson and Delilah (1996)
# 76434          0        0        0                               David (1997)
# 150491         0        0        0                              Samson (2018)
#
#          is_older  duration_hours
# movie_id
# 942          True        3.533333
# 2119         True        3.666667
# 2531         True        1.583333
# 3151         True        1.566667
# 3167         True        1.700000
# 4274         True        2.333333
# 5347         True        3.333333
# 5854         True        2.800000
# 6677         True        1.766667
# 6836         True        2.200000
# 7372         True        2.250000
# 9031         True        2.000000
# 10368        True        1.883333
# 12762        True        1.683333
# 12825        True        1.816667
# 16849        True        1.500000
# 17935        True        1.500000
# 19554       False        1.550000
# 21090       False        1.500000
# 21135       False        1.500000
# 21910        True        1.600000
# 24080       False        2.166667
# 26238        True        2.166667
# 26341       False        2.100000
# 35707        True        6.183333
# 42350        True        0.683333
# 42430        True        1.866667
# 51072        True        1.200000
# 51481       False        3.333333
# 54251       False        3.000000
# 56046        True        1.500000
# 58832       False        3.333333
# 60587        True        3.000000
# 61169       False        2.833333
# 65370       False        2.300000
# 76154        True        2.866667
# 76434        True        3.166667
# 150491      False        1.933333
#
# [38 rows x 21 columns]
#
# Genre: Biography
#                       movie_title  release_year      genre  duration  \
# movie_id
# 77        Abe Lincoln in Illinois          1940  Biography       110
# 124               Beloved Infidel          1959  Biography       123
# 231              Alfred the Great          1969  Biography       120
# 459          An Angel at My Table          1990  Biography       158
# 528             Antonio di Padova          1949  Biography        90
# ...                           ...           ...        ...       ...
# 222456                Flamin' Hot          2023  Biography        99
# 224901                     Johnny          2022  Biography       119
# 229806                  Bastarden          2023  Biography       127
# 229829          The Featherweight          2023  Biography        99
# 232816       La stoccata vincente          2023  Biography       107
#
#                                         country         directors  \
# movie_id
# 77                                United States     John Cromwell
# 124                               United States        Henry King
# 231                               Great Britain      Clive Donner
# 459       New Zealand, Australia, Great Britain      Jane Campion
# 528                                       Italy   Piero Francisci
# ...                                         ...               ...
# 222456                            United States      Eva Longoria
# 224901                                   Poland   Daniel Jaroszek
# 229806                          Denmark, Norway     Nikolaj Arcel
# 229829                            United States    Robert Kolodny
# 232816                                    Italy  Nicola Campiotti
#
#                                                      actors  avg_vote  \
# movie_id
# 77        Raymond Massey, Ruth Gordon, Gene Lockhart, Ma...       6.3
# 124       Gregory Peck, Deborah Kerr, Eddie Albert, Phil...       5.8
# 231       David Hemmings, Prunella Ransome, Michael York...       8.1
# 459       Kerry Fox, Alexia Keogh, Karen Fergusson, Iris...       7.6
# 528       Aldo Fiorelli, Aldo Fabrizi, Silvana Pampanini...       2.4
# ...                                                     ...       ...
# 222456    Tony Shalhoub, Dennis Haysbert, Matt Walsh, Br...       6.6
# 224901    Dawid Ogrodnik, Piotr Trojan, Beata Zygarlicka...       6.5
# 229806    Mads Mikkelsen, Gustav Lindh, Amanda Collin, K...       6.5
# 229829    Stephen Lang, Ron Livingston, Keir Gilchrist, ...       6.3
# 232816    Alessio Vassallo, Flavio Insinna, Elena Funari...       4.5
#
#           critics_vote  public_vote  ...  \
# movie_id                             ...
# 77                6.00          7.0  ...
# 124               6.00          6.0  ...
# 231               8.00          8.0  ...
# 459               7.20          8.0  ...
# 528               3.75          1.0  ...
# ...                ...          ...  ...
# 222456             NaN          7.0  ...
# 224901            6.00          7.0  ...
# 229806            5.67          7.0  ...
# 229829             NaN          6.0  ...
# 232816             NaN          5.0  ...
#
#                                                 description  \
# movie_id
# 77        From lumberjack in his native Illinois to the ...
# 124       The British journalist Sheilah Graham, who has...
# 231       The noble Alfredo, who intends to become a mon...
# 459       Biography of the New Zealand poet and novelist...
# 528       The re-enactment of the life and works of Sain...
# ...                                                     ...
# 222456    Richard Montañez began to work as custodian an...
# 224901    After an order of the court sent him to work a...
# 229806    Denmark, mid -1700s. Throughout his life, Ludv...
# 229829    1964. A former boxing champion, now fifty year...
# 232816    The true story of the prodigy of fencing Paolo...
#
#                                                       notes humor  rhythm  \
# movie_id
# 77        Anthology of famous episodes in American histo...     0       1
# 124       A bitter passion narrated with almost all the ...     0       2
# 231       Good historical British production. Clive Donn...     0       3
# 459       From the director of "Lezioni di piano", a tru...     1       3
# 528                                                     NaN     0       1
# ...
# 232919    Once Ok-Ju worked as a bodyguard and was one o...
# 232920    A great passionate of crime stories is trapped...
#
#                                                       notes humor  rhythm  \
# movie_id
# 24                   Approximation and mediocrity in go-go.     1       2
# 54        Columbia took advantage of Dick Powell's recen...     1       3
# 67        Specialist Lamont Johnson has built an effecti...     0       3
# 135       A dry and rigorous film aimed at reconstructin...     0       2
# 164       Although the screenplay is by Horace McCoy and...     0       1
# ...                                                     ...   ...     ...
# 232184                                                  NaN     0       0
# 232757                                                  NaN     0       0
# 232817                      Freely taken from a true story.     0       0
# 232919                                                  NaN     0       0
# 232920                                                  NaN     0       0
#
#           effort  tension  erotism                        title_year is_older  \
# movie_id
# 24             0        1        0        A... come assassino (1966)     True
# 54             1        3        1             Johnny O'Clock (1947)     True
# 67             1        3        0      You'll Like My Mother (1973)     True
# 135            3        3        0         L'affaire Dominici (1973)     True
# 164            0        3        0          Dangerous Mission (1954)     True
# ...          ...      ...      ...                               ...      ...
# 232184         0        0        0                    Nowhere (2023)    False
# 232757         0        0        0      Hidden Family Secrets (2021)    False
# 232817         0        0        0         Gold Digger Killer (2021)    False
# 232919         0        0        0                  Ballelina (2023)    False
# 232920         0        0        0  Invitación a un Asesinato (2023)    False
#
#           duration_hours
# movie_id
# 24              1.333333
# 54              1.583333
# 67              1.566667
# 135             1.766667
# 164             1.250000
# ...                  ...
# 232184          1.816667
# 232757          1.450000
# 232817          1.450000
# 232919          1.533333
# 232920          1.533333
#
# [3701 rows x 21 columns]
#
# Genre: War
#                              movie_title  release_year genre  duration  \
# movie_id
# 95                     Achtung! Banditi!          1951   War       100
# 110                 Farewell to the King          1988   War       107
# 111                   A Farewell to Arms          1932   War        78
# 143                          The Valiant          1961   War        90
# 506                            Gallipoli          1981   War       120
# ...                                  ...           ...   ...       ...
# 216931                            Nezouh          2022   War       100
# 217227                              Sisu          2022   War        91
# 218237                  Kampen om Narvik          2022   War       108
# 219042              Burning at Both Ends          2021   War       110
# 229814    The Caine Mutiny Court-Martial          2023   War       108
#
#                                country                     directors  \
# movie_id
# 95                               Italy                 Carlo Lizzani
# 110                      United States                   John Milius
# 111                      United States                 Frank Borzage
# 143               Italy, Great Britain                Roy Ward Baker
# 506                          Australia                    Peter Weir
# ...                                ...                           ...
# 216931    Syria, Great Britain, France                Soudade Kaadan
# 217227                         Finland              Jalmari Helander
# 218237                          Norway              Erik Skjoldbjærg
# 219042                   United States  Matthew Hill, Landon Johnson
# 229814                   United States              William Friedkin
#
#                                                      actors  avg_vote  \
# movie_id
# 95        Gina Lollobrigida, Andrea Checchi, Vittorio Du...       7.0
# 110       Nick Nolte, Nigel Havers, James Fox, Frank McR...       6.9
# 111       Gary Cooper, Helen Hayes, Adolphe Menjou, Mary...       6.9
# 143       Ettore Manni, John Mills, Roberto Risso, Rober...       4.8
# 506       Mel Gibson, Mark Lee, Bill Kerr, Charles Latha...       7.7
# ...                                                     ...       ...
# 216931    Samer al Masri, Kinda Alloush, Nizar Alani, Ha...       6.9
# 217227    Aksel Hennie, Jack Doolan, Onni Tommila, Mimos...       6.0
# 218237    Henrik Mestad, Stig Henrik Hoff, Kristine Hart...       6.2
# 219042    Cary Elwes, Jason Patric, Judd Hirsch, Sebasti...       4.8
# 229814    Kiefer Sutherland, Jason Clarke, Jake Lacy, Mo...       7.4
#
#           critics_vote  public_vote  ...  \
# movie_id                             ...
# 95                6.92          7.0  ...
# 110               6.60          7.0  ...
# 111               7.20          7.0  ...
# 143               4.00          6.0  ...
# 506               8.00          7.0  ...
# ...                ...          ...  ...
# 216931            8.00          6.0  ...
# 217227            6.00          6.0  ...
# 218237            6.50          6.0  ...
# 219042            4.00          6.0  ...
# 229814            7.50          7.0  ...
#
#                                                 description  \
# movie_id
# 95        The war is about to end and in Genoa a group o...
# 110       Learoyd, a former sergeant who defected from t...
# 111       Federic, an American journalist (Cooper), volu...
# 143       During the Second World War some Italian diver...
# 506       Archy and Frank are two Australian friends who...
# ...                                                     ...
# 216931    Although the bombs continue to fall on Damascu...
# 217227    When a former soldier who discovered a gold de...
# 218237    April 1940. The eyes of the world are focused ...
# 219042    Removed behind the enemy lines, a small group ...
# 229814    A Navy officer is tried by mutiny for tearing ...
#
#                                                       notes humor  rhythm  \
# movie_id
# 95        Directorial debut for Carlo Lizzani who takes ...     0       2
# 110       Battles, massacres, and a bitter ending. The u...     1       2
# 111       It is the great love, against the backdrop of ...     1       3
# 143       The film evokes a real war episode and is insp...     0       2
# 506       Weir manages to capture the moment of emotion ...     2       3
# ...                                                     ...   ...     ...
# 216931                                                  NaN     0       0
# 217227                                                  NaN     0       0
# 218237                                                  NaN     0       0
# 219042                                                  NaN     0       0
# 229814                                                  NaN     0       0
#
#           effort  tension  erotism                             title_year  \
# movie_id
# 95             4        2        0               Achtung! Banditi! (1951)
# 110            1        2        1            Farewell to the King (1988)
# 111            2        3        1              A Farewell to Arms (1932)
# 143            2        1        0                     The Valiant (1961)
# 506            3        3        1                       Gallipoli (1981)
# ...          ...      ...      ...                                    ...
# 216931         0        0        0                          Nezouh (2022)
# 217227         0        0        0                            Sisu (2022)
# 218237         0        0        0                Kampen om Narvik (2022)
# 219042         0        0        0            Burning at Both Ends (2021)
# 229814         0        0        0  The Caine Mutiny Court-Martial (2023)
#
#          is_older  duration_hours
# movie_id
# 95           True        1.666667
# 110          True        1.783333
# 111          True        1.300000
# 143          True        1.500000
# 506          True        2.000000
# ...           ...             ...
# 216931      False        1.666667
# 217227      False        1.516667
# 218237      False        1.800000
# 219042      False        1.833333
# 229814      False        1.800000
#
# [405 rows x 21 columns]
#
# Genre: Western
#                                movie_title  release_year    genre  duration  \
# movie_id
# 61                           The Appaloosa          1966  Western        98
# 104                       Mail Order Bride          1963  Western        90
# 181       Die Flusspiraten vom Mississippi          1964  Western        86
# 204                 Drums Across the River          1954  Western        78
# 207                   Al di là della legge          1968  Western        95
# ...                                    ...           ...      ...       ...
# 205581                           Old Henry          2021  Western        99
# 207392                        West of Hell          2018  Western        80
# 209542       Monta in sella!! Figlio di...          1972  Western        95
# 216836                   Dead for A Dollar          2022  Western       124
# 232755                         Organ Trail          2023  Western       112
#
#                         country             directors  \
# movie_id
# 61                United States       Sidney J. Furie
# 104               United States          Burt Kennedy
# 181                     Germany         Jürgen Roland
# 204               United States          Nathan Juran
# 207                       Italy       Giorgio Stegani
# ...                         ...                   ...
# 205581            United States       Potsy Ponciroli
# 207392            United States        Michael Steves
# 209542             Italy, Spain          Tonino Ricci
# 216836    Canada, United States           Walter Hill
# 232755            United States  Michael Patrick Jann
#
#                                                      actors  avg_vote  \
# movie_id
# 61        Marlon Brando, Anjanette Comer, John Saxon, Em...       6.9
# 104       Buddy Ebsen, Keir Dullea, Warren Oates, Marie ...       6.1
# 181       Hansjörg Felmy, Sabine Sinjen, Horst Frank, Br...       4.5
# 204       Audie Murphy, Lisa Gaye, Walter Brennan, Lyle ...       7.4
# 207       Lee Van Cleef, Antonio Sabato, Graziella Grana...       5.1
# ...                                                     ...       ...
# 205581    Stephen Dorff, Tim Blake Nelson, Richard Speig...       6.9
# 207392    Tony Todd, Michael Eklund, Lance Henriksen, Ju...       3.0
# 209542    Mark Damon, Rosalba Neri, Stelvio Rosi, Gianca...       3.5
# 216836    Willem Dafoe, Rachel Brosnahan, Hamish Linklat...       6.3
# 232755    Zoé De Grand Maison, Mather Zickel, Lisa LoCic...       5.0
#
#           critics_vote  public_vote  ...  \
# movie_id                             ...
# 61                7.00          7.0  ...
# 104               6.00          6.0  ...
# 181               4.00          5.0  ...
# 204               8.00          7.0  ...
# 207               5.29          5.0  ...
# ...                ...          ...  ...
# 205581            6.58          7.0  ...
# 207392             NaN          3.0  ...
# 209542            4.00          3.0  ...
# 216836            6.73          6.0  ...
# 232755            5.50          5.0  ...
#
#                                                 description  \
# movie_id
# 61        On the Mexican frontier, a dramatic rivalry be...
# 104       Restless and rebellious, Lee Karey is entruste...
# 181       A mysterious stranger arrives in Black Water. ...
# 204       The greed of the whites sows discord among the...
# 207       Cudlip, a wanderer who travels the West accomp...
# ...                                                     ...
# 205581    Henry (Tim Blake Nelson), a widowed farmer, an...
# 207392    A pistoler, a former vendial slave and a fugit...
# 209542    Three men and a woman accept the proposal of a...
# 216836    A famous head hunter comes across one of his m...
# 232755    The young abigale Archer is located alone in M...
#
#                                                       notes humor  rhythm  \
# movie_id
# 61        A very original western for the subject and fo...     0       2
# 104       A western tinged with comedy, according to con...     1       2
# 181                                                     NaN     0       2
# 204                                                     NaN     1       3
# 207       Italian Western of discreet workmanship, cente...     1       2
# ...                                                     ...   ...     ...
# 205581                                                  NaN     0       0
# 207392                                                  NaN     0       0
# 209542                                                  NaN     0       0
# 216836                                                  NaN     0       0
# 232755                                                  NaN     0       0
#
#           effort  tension  erotism                               title_year  \
# movie_id
# 61             1        3        1                     The Appaloosa (1966)
# 104            0        1        0                  Mail Order Bride (1963)
# 181            0        1        0  Die Flusspiraten vom Mississippi (1964)
# 204            0        0        0            Drums Across the River (1954)
# 207            1        1        0              Al di là della legge (1968)
# ...          ...      ...      ...                                      ...
# 205581         0        0        0                         Old Henry (2021)
# 207392         0        0        0                      West of Hell (2018)
# 209542         0        0        0     Monta in sella!! Figlio di... (1972)
# 216836         0        0        0                 Dead for A Dollar (2022)
# 232755         0        0        0                       Organ Trail (2023)
#
#          is_older  duration_hours
# movie_id
# 61           True        1.633333
# 104          True        1.500000
# 181          True        1.433333
# 204          True        1.300000
# 207          True        1.583333
# ...           ...             ...
# 205581      False        1.650000
# 207392      False        1.333333
# 209542       True        1.583333
# 216836      False        2.066667
# 232755      False        1.866667
#
# [1146 rows x 21 columns]

# %%
year_genre_groups = df.groupby(['release_year', 'genre'])  # Groups by year and genre

# %% [markdown]
# # Aggregation
#
# After grouping, you might want to perform aggregation operations like sum, mean, count, etc., to summarize the data.

# %%
# Simple Aggregation - Calculating the Average
avg_duration_by_genre = df.groupby('genre')['duration'].mean()  # Average duration per genre
print(avg_duration_by_genre)
# Out:
# genre
# Action             101.682599
# Adventure          102.870079
# Animation           88.925651
# Biblical           137.210526
# Biography          120.602920
# Comedy              97.881409
# Crime               98.939914
# Documentary         92.641638
# Drama              105.271266
# Erotico             90.893617
# Fantasy            105.612326
# Gangster           117.803571
# Grotesque           99.851852
# History            127.159420
# Horror              92.603867
# Musical            106.240654
# Mythology           97.969697
# Mélo               107.836538
# Noir                98.428571
# Romantic            94.778571
# Sci-Fi             102.097238
# Short Movie        210.500000
# Sperimental         97.716049
# Sport               95.428571
# Spy                105.333333
# Stand-up Comedy     73.000000
# Super-hero         121.855422
# Thriller            97.957849
# War                111.306173
# Western             95.800175
# Name: duration, dtype: float64

# %%
# Multiple Aggregations on a Single Column
stats_by_genre = df.groupby('genre')['avg_vote'].agg([np.mean, np.std, np.min, np.max])
print(stats_by_genre)
# Out:
#                      mean       std  min   max
# genre
# Action           5.123898  1.399433  1.0   9.0
# Adventure        5.545866  1.324040  1.4   9.3
# Animation        6.118030  1.281681  1.6   9.3
# Biblical         5.184211  1.273753  2.9   8.2
# Biography        5.949051  1.208300  1.0  10.0
# Comedy           5.482645  1.355306  1.0  10.0
# Crime            6.142918  1.167942  2.7   8.8
# Documentary      6.564749  1.180058  1.0  10.0
# Drama            6.292677  1.302034  1.0  10.0
# Erotico          4.052766  1.323337  1.0   7.9
# Fantasy          5.486282  1.322481  1.3   9.4
# Gangster         6.614286  1.383333  2.5   9.0
# Grotesque        6.458848  1.250535  2.3   9.1
# History          5.887681  1.245398  2.7   8.8
# Horror           5.225874  1.301247  1.3   9.1
# Musical          6.016121  1.474926  1.8   9.0
# Mythology        4.631818  1.298183  2.2   8.0
# Mélo             6.715385  1.256731  3.6   8.6
# Noir             6.985294  1.104915  3.4   9.5
# Romantic         4.883367  1.532141  1.0   8.8
# Sci-Fi           5.484309  1.365001  1.4   9.2
# Short Movie      6.800000  0.843801  5.3   7.7
# Sperimental      6.547531  1.170454  2.0   9.0
# Sport            5.228571  1.879463  3.0   7.5
# Spy              5.769167  1.399898  2.0   8.8
# Stand-up Comedy  7.325000  0.793200  6.8   8.5
# Super-hero       5.833735  1.032671  2.3   7.5
# Thriller         5.530586  1.264825  1.0   9.3
# War              6.293086  1.301066  1.7   9.3
# Western          5.744590  1.306447  1.5   8.9

# %%
# Different Aggregations for Different Columns
complex_aggregation = df.groupby('genre').agg({
    'duration': np.mean,  # average duration
    'avg_vote': [np.min, np.max],  # min and max average votes
    'public_vote': 'sum'  # total of public votes
})

# %%
complex_aggregation
# Out:
#                    duration avg_vote       public_vote
#                        mean      min   max         sum
# genre
# Action           101.682599      1.0   9.0     11369.0
# Adventure        102.870079      1.4   9.3      8747.0
# Animation         88.925651      1.6   9.3      6639.0
# Biblical         137.210526      2.9   8.2       202.0
# Biography        120.602920      1.0  10.0      4136.0
# Comedy            97.881409      1.0  10.0     51634.0
# Crime             98.939914      2.7   8.8      2953.0
# Documentary       92.641638      1.0  10.0     13371.0
# Drama            105.271266      1.0  10.0     76234.0
# Erotico           90.893617      1.0   7.9       981.0
# Fantasy          105.612326      1.3   9.4      2830.0
# Gangster         117.803571      2.5   9.0       378.0
# Grotesque         99.851852      2.3   9.1      1578.0
# History          127.159420      2.7   8.8       823.0
# Horror            92.603867      1.3   9.1     12917.0
# Musical          106.240654      1.8   9.0      2647.0
# Mythology         97.969697      2.2   8.0       338.0
# Mélo             107.836538      3.6   8.6       705.0
# Noir              98.428571      3.4   9.5      1640.0
# Romantic          94.778571      1.0   8.8      4906.0
# Sci-Fi           102.097238      1.4   9.2      5064.0
# Short Movie      210.500000      5.3   7.7        41.0
# Sperimental       97.716049      2.0   9.0      1018.0
# Sport             95.428571      3.0   7.5        37.0
# Spy              105.333333      2.0   8.8      1406.0
# Stand-up Comedy   73.000000      6.8   8.5        32.0
# Super-hero       121.855422      2.3   7.5       488.0
# Thriller          97.957849      1.0   9.3     21048.0
# War              111.306173      1.7   9.3      2596.0
# Western           95.800175      1.5   8.9      6739.0

# %% [markdown]
# **Aggregating Without Grouping:**
# Sometimes, you may want to perform aggregations without the need to group the data.

# %%
# Overall Summary Statistics
overall_stats = df[['duration', 'avg_vote']].describe()
overall_stats
# Out:
#            duration      avg_vote
# count  41399.000000  41399.000000
# mean     100.537163      5.801522
# std       27.260962      1.403861
# min       41.000000      1.000000
# 25%       90.000000      4.800000
# 50%       96.000000      5.900000
# 75%      107.000000      6.900000
# max     1525.000000     10.000000

# %% [markdown]
# **df.count():** This method returns the number of non-null values in each DataFrame column. It can be used to count the number of non-null values in each column individually.

# %%
# Create a DataFrame
data = {'A': [1, 2, None], 'B': [4, None, 6], 'C': [5, 8, 9]}
data_df = pd.DataFrame(data)

# Count non-null values in each column
counts = data_df.count()
print(counts)
# Out:
# A    2
# B    2
# C    3
# dtype: int64

# %% [markdown]
# **df.value_counts():** This method returns the frequency counts of unique values in a Series. It is typically used on a single column of the DataFrame and is useful for analyzing the distribution of values within that column.

# %%
# Value Counts
df['movie_title'].value_counts()
# Out:
# movie_title
# Les Vampires                 10
# Pinocchio                     8
# Riget II                      6
# Dr. Jekyll and Mr. Hyde       5
# Sibiriada                     5
#                              ..
# Farelavita                    1
# A, B, C... Manhattan          1
# Parfait amour!                1
# A Season for Miracles         1
# Invitación a un Asesinato     1
# Name: count, Length: 39531, dtype: int64

# %% [markdown]
# **Custom Aggregation Functions:**
# Pandas allows you to define and use custom aggregation functions for more specific data analysis needs.

# %%
# Using a Custom Function for Aggregation
def range_func(series):
    return series.max() - series.min()

range_by_genre = df.groupby('genre')['duration'].agg(range_func)  # Range of durations by genre
range_by_genre
# Out:
# genre
# Action              197
# Adventure           355
# Animation          1129
# Biblical            330
# Biography           267
# Comedy              558
# Crime               135
# Documentary         859
# Drama              1484
# Erotico              61
# Fantasy             202
# Gangster            245
# Grotesque           236
# History             560
# Horror              213
# Musical             247
# Mythology           104
# Mélo                151
# Noir                110
# Romantic            150
# Sci-Fi              259
# Short Movie         487
# Sperimental         774
# Sport                34
# Spy                 115
# Stand-up Comedy      27
# Super-hero          101
# Thriller            550
# War                 655
# Western             145
# Name: duration, dtype: int64

# %% [markdown]
# **Renaming Grouped Aggregation Results:**
# It is often useful to rename the results of aggregations for clarity or further analysis.

# %%
# Renaming Aggregation Results
renamed_aggregations = df.groupby('genre')['avg_vote'].agg([
    ('Average Rating', 'mean'),  # Renames the mean result to 'Average Rating'
    ('Rating Standard Deviation', 'std')  # Renames the std result to 'Rating Standard Deviation'
])
renamed_aggregations
# Out:
#                  Average Rating  Rating Standard Deviation
# genre
# Action                 5.123898                   1.399433
# Adventure              5.545866                   1.324040
# Animation              6.118030                   1.281681
# Biblical               5.184211                   1.273753
# Biography              5.949051                   1.208300
# Comedy                 5.482645                   1.355306
# Crime                  6.142918                   1.167942
# Documentary            6.564749                   1.180058
# Drama                  6.292677                   1.302034
# Erotico                4.052766                   1.323337
# Fantasy                5.486282                   1.322481
# Gangster               6.614286                   1.383333
# Grotesque              6.458848                   1.250535
# History                5.887681                   1.245398
# Horror                 5.225874                   1.301247
# Musical                6.016121                   1.474926
# Mythology              4.631818                   1.298183
# Mélo                   6.715385                   1.256731
# Noir                   6.985294                   1.104915
# Romantic               4.883367                   1.532141
# Sci-Fi                 5.484309                   1.365001
# Short Movie            6.800000                   0.843801
# Sperimental            6.547531                   1.170454
# Sport                  5.228571                   1.879463
# Spy                    5.769167                   1.399898
# Stand-up Comedy        7.325000                   0.793200
# Super-hero             5.833735                   1.032671
# Thriller               5.530586                   1.264825
# War                    6.293086                   1.301066
# Western                5.744590                   1.306447
